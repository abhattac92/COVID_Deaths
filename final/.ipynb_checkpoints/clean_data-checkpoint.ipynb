# %%
import os
import glob
import pandas as pd
import datetime
from timeit import default_timer as timer
import numpy as np
from datetime import datetime
import calendar

# %%
# this code was used to create a smaller file. disregard for any further work

# %%
# Import our input dataset all merged files for 1 year of data. 09/19-09/20
data = pd.read_csv('../../../final_product/data/combined_csv.csv')
data.head()
# Out:
#    backers_count                                              blurb  \
# 0            598  Unique Matte finish, 3D print filament that re...
# 1              0  My wife is pregnant and I promised my toddler ...
# 2              3  Salty Dawg Customs is a small woodworking shop...
# 3              3  Spread love into everyone's life with our vari...
# 4             27  Wooden kazoos that are both very dynamic, and ...
#
#                                             category  \
# 0  {"id":331,"name":"3D Printing","slug":"technol...
# 1  {"id":356,"name":"Woodworking","slug":"crafts/...
# 2  {"id":356,"name":"Woodworking","slug":"crafts/...
# 3  {"id":54,"name":"Mixed Media","slug":"art/mixe...
# 4  {"id":356,"name":"Woodworking","slug":"crafts/...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                   69661.0      GB       the United Kingdom  1474531768
# 1                       0.0      US        the United States  1405638255
# 2                      70.0      US        the United States  1435757008
# 3                      35.0      US        the United States  1438118556
# 4                     941.0      US        the United States  1507246349
#
#                                              creator currency currency_symbol  \
# 0  {"id":73000579,"name":"Steelmans","slug":"stee...      GBP               £
# 1  {"id":1119516683,"name":"Justin Haas","is_regi...      USD               $
# 2  {"id":889446413,"name":"Kevin Hart","is_regist...      USD               $
# 3  {"id":2112235325,"name":"Heather Johnson (dele...      USD               $
# 4  {"id":841853400,"name":"Leo Debevc","is_regist...      USD               $
#
#    ...  staff_pick       state  state_changed_at  static_usd_rate  \
# 0  ...       False  successful        1496851277         1.290526
# 1  ...       False      failed        1409178684         1.000000
# 2  ...       False      failed        1438782247         1.000000
# 3  ...       False      failed        1441581323         1.000000
# 4  ...       False      failed        1509875777         1.000000
#
#                                                 urls   usd_pledged  usd_type  \
# 0  {"web":{"project":"https://www.kickstarter.com...  69687.098894  domestic
# 1  {"web":{"project":"https://www.kickstarter.com...      0.000000  domestic
# 2  {"web":{"project":"https://www.kickstarter.com...     70.000000  domestic
# 3  {"web":{"project":"https://www.kickstarter.com...     35.000000  domestic
# 4  {"web":{"project":"https://www.kickstarter.com...    941.000000  domestic
#
#    last_update_published_at unread_messages_count  unseen_activity_count
# 0                       NaN                   NaN                    NaN
# 1                       NaN                   NaN                    NaN
# 2                       NaN                   NaN                    NaN
# 3                       NaN                   NaN                    NaN
# 4                       NaN                   NaN                    NaN
#
# [5 rows x 41 columns]

# %%
pd.set_option('display.max_columns', None)
data
# Out:
#          backers_count                                              blurb  \
# 0                  598  Unique Matte finish, 3D print filament that re...
# 1                    0  My wife is pregnant and I promised my toddler ...
# 2                    3  Salty Dawg Customs is a small woodworking shop...
# 3                    3  Spread love into everyone's life with our vari...
# 4                   27  Wooden kazoos that are both very dynamic, and ...
# ...                ...                                                ...
# 2760168           2246  A framed high-definition screen and integrated...
# 2760169              3  We want to develop a smaller, electrically and...
# 2760170              0  A few die hard nfl fans on the wrong side of t...
# 2760171            242  Publicación digital del "Calendario Irresistib...
# 2760172              0  Fun and safe tire playground, custom built by ...
#
#                                                   category  \
# 0        {"id":331,"name":"3D Printing","slug":"technol...
# 1        {"id":356,"name":"Woodworking","slug":"crafts/...
# 2        {"id":356,"name":"Woodworking","slug":"crafts/...
# 3        {"id":54,"name":"Mixed Media","slug":"art/mixe...
# 4        {"id":356,"name":"Woodworking","slug":"crafts/...
# ...                                                    ...
# 2760168  {"id":52,"name":"Hardware","slug":"technology/...
# 2760169  {"id":52,"name":"Hardware","slug":"technology/...
# 2760170  {"id":239,"name":"Radio & Podcasts","slug":"pu...
# 2760171  {"id":325,"name":"Calendars","slug":"publishin...
# 2760172  {"id":258,"name":"Architecture","slug":"design...
#
#          converted_pledged_amount country country_displayable_name  \
# 0                         69661.0      GB       the United Kingdom
# 1                             0.0      US        the United States
# 2                            70.0      US        the United States
# 3                            35.0      US        the United States
# 4                           941.0      US        the United States
# ...                           ...     ...                      ...
# 2760168                  787612.0      US        the United States
# 2760169                     301.0      US        the United States
# 2760170                       0.0      GB       the United Kingdom
# 2760171                    7056.0      US        the United States
# 2760172                       0.0      US        the United States
#
#          created_at                                            creator  \
# 0        1474531768  {"id":73000579,"name":"Steelmans","slug":"stee...
# 1        1405638255  {"id":1119516683,"name":"Justin Haas","is_regi...
# 2        1435757008  {"id":889446413,"name":"Kevin Hart","is_regist...
# 3        1438118556  {"id":2112235325,"name":"Heather Johnson (dele...
# 4        1507246349  {"id":841853400,"name":"Leo Debevc","is_regist...
# ...             ...                                                ...
# 2760168  1398954860  {"id":1630737886,"name":"Electric Objects","sl...
# 2760169  1547491873  {"id":544645699,"name":"Bret Raymis","slug":"p...
# 2760170  1402351719  {"id":1020137667,"name":"Marc Beaton (deleted)...
# 2760171  1518734218  {"id":873433688,"name":"Rubén Jungbluth","is_r...
# 2760172  1477336137  {"id":575570128,"name":"Erin Stodolak","is_reg...
#
#         currency currency_symbol  currency_trailing_code current_currency  \
# 0            GBP               £                   False              USD
# 1            USD               $                    True              USD
# 2            USD               $                    True              USD
# 3            USD               $                    True              USD
# 4            USD               $                    True              USD
# ...          ...             ...                     ...              ...
# 2760168      USD               $                    True              USD
# 2760169      USD               $                    True              USD
# 2760170      GBP               £                   False              USD
# 2760171      USD               $                    True              USD
# 2760172      USD               $                    True              USD
#
#            deadline  disable_communication friends   fx_rate      goal  \
# 0        1496851276                  False     NaN  1.291356    9000.0
# 1        1409178684                  False     NaN  1.000000     500.0
# 2        1438782247                  False     NaN  1.000000    1900.0
# 3        1441581323                  False     NaN  1.000000     100.0
# 4        1509875776                  False     NaN  1.000000    2500.0
# ...             ...                    ...     ...       ...       ...
# 2760168  1407422151                  False     NaN  1.000000   25000.0
# 2760169  1575183540                  False     NaN  1.000000  500000.0
# 2760170  1403640082                  False     NaN  1.291356     600.0
# 2760171  1524157200                  False     NaN  1.000000   35000.0
# 2760172  1478980838                  False     NaN  1.000000     400.0
#
#                  id is_backing  is_starrable is_starred  launched_at  \
# 0        1424538693        NaN         False        NaN   1493827276
# 1         442780559        NaN         False        NaN   1406586715
# 2         387878803        NaN         False        NaN   1436190247
# 3         697381509        NaN         False        NaN   1438989323
# 4        1961865232        NaN         False        NaN   1507280176
# ...             ...        ...           ...        ...          ...
# 2760168   502128093        NaN         False        NaN   1404830151
# 2760169   267581260        NaN         False        NaN   1572727216
# 2760170  1893715389        NaN         False        NaN   1402430482
# 2760171  1120063367        NaN         False        NaN   1519072257
# 2760172  1866136332        NaN         False        NaN   1477422038
#
#                                                   location  \
# 0        {"id":12602144,"name":"Leicestershire","slug":...
# 1        {"id":2442327,"name":"Louisville","slug":"loui...
# 2        {"id":2380358,"name":"Cincinnati","slug":"cinc...
# 3        {"id":2458386,"name":"New Hartford","slug":"ne...
# 4        {"id":2356724,"name":"Ashtabula","slug":"ashta...
# ...                                                    ...
# 2760168  {"id":2459115,"name":"New York","slug":"new-yo...
# 2760169  {"id":2357536,"name":"Austin","slug":"austin-t...
# 2760170  {"id":30079,"name":"Newcastle upon Tyne","slug...
# 2760171  {"id":2450022,"name":"Miami","slug":"miami-fl"...
# 2760172  {"id":2378695,"name":"Chattanooga","slug":"cha...
#
#                                                       name permissions  \
# 0                           MATTEFORGE : 3D Print Filament         NaN
# 1                                       The Pirate Bedroom         NaN
# 2        Salty Dawg Customs - Custom, Handmade, Quality...         NaN
# 3                                             Paper Hearts         NaN
# 4        Wooden Kazoos/Membranophones Handcrafted in Oh...         NaN
# ...                                                    ...         ...
# 2760168          Electric Objects: A Computer Made for Art         NaN
# 2760169  Very Safe, Long Life, Zinc Magnetic Particle F...         NaN
# 2760170                              firstandtenuk podcast         NaN
# 2760171  CALENDARIO LUNAR PARA IMPULSAR NEGOCIOS 2018 -...         NaN
# 2760172                               Silas's Tire Kingdom         NaN
#
#                                                      photo    pledged  \
# 0        {"key":"assets/014/106/575/cd2294e8b6ff0a4663d...   53999.00
# 1        {"key":"assets/011/791/735/bbb921a2f430dd206d4...       0.00
# 2        {"key":"assets/012/184/409/1efdd36d3efc3ee9f37...      70.00
# 3        {"key":"assets/012/210/140/abf529eaf4cbbff9f72...      35.00
# 4        {"key":"assets/018/627/297/fb4db0fe457101ddfe4...     941.00
# ...                                                    ...        ...
# 2760168  {"key":"assets/011/696/686/60d6fa9c3f544a5effd...  787612.73
# 2760169  {"key":"assets/027/037/617/24431c25c97a88c90a8...     301.00
# 2760170  {"key":"assets/011/722/335/3d4dd07177d8a1941ab...       0.00
# 2760171  {"key":"assets/020/250/738/357280b472e7a9b848f...    7056.20
# 2760172  {"key":"assets/014/243/468/c92c27930d8bf7a0221...       0.00
#
#                                                    profile  \
# 0        {"id":2689913,"project_id":2689913,"state":"ac...
# 1        {"id":1198148,"project_id":1198148,"state":"in...
# 2        {"id":1991449,"project_id":1991449,"state":"in...
# 3        {"id":2039195,"project_id":2039195,"state":"in...
# 4        {"id":3171342,"project_id":3171342,"state":"in...
# ...                                                    ...
# 2760168  {"id":1002799,"project_id":1002799,"state":"ac...
# 2760169  {"id":3580581,"project_id":3580581,"state":"in...
# 2760170  {"id":1061477,"project_id":1061477,"state":"in...
# 2760171  {"id":3311397,"project_id":3311397,"state":"in...
# 2760172  {"id":2732072,"project_id":2732072,"state":"in...
#
#                                                       slug  \
# 0                             matteforge-3d-print-filament
# 1                                       the-pirate-bedroom
# 2        salty-dawg-customs-custom-handmade-quality-fur...
# 3                                             paper-hearts
# 4        wooden-kazoos-membranophones-handcrafted-in-oh...
# ...                                                    ...
# 2760168           electric-objects-a-computer-made-for-art
# 2760169  very-safe-long-life-zinc-magnetic-particle-flo...
# 2760170                              firstandtenuk-podcast
# 2760171  calendario-lunar-para-impulsar-negocios-2018-2019
# 2760172                                silass-tire-kingdom
#
#                                                 source_url  spotlight  \
# 0        https://www.kickstarter.com/discover/categorie...       True
# 1        https://www.kickstarter.com/discover/categorie...      False
# 2        https://www.kickstarter.com/discover/categorie...      False
# 3        https://www.kickstarter.com/discover/categorie...      False
# 4        https://www.kickstarter.com/discover/categorie...      False
# ...                                                    ...        ...
# 2760168  https://www.kickstarter.com/discover/categorie...       True
# 2760169  https://www.kickstarter.com/discover/categorie...      False
# 2760170  https://www.kickstarter.com/discover/categorie...      False
# 2760171  https://www.kickstarter.com/discover/categorie...      False
# 2760172  https://www.kickstarter.com/discover/categorie...      False
#
#          staff_pick       state  state_changed_at  static_usd_rate  \
# 0             False  successful        1496851277         1.290526
# 1             False      failed        1409178684         1.000000
# 2             False      failed        1438782247         1.000000
# 3             False      failed        1441581323         1.000000
# 4             False      failed        1509875777         1.000000
# ...             ...         ...               ...              ...
# 2760168        True  successful        1407422151         1.000000
# 2760169       False      failed        1575183540         1.000000
# 2760170       False      failed        1403640082         1.680602
# 2760171       False      failed        1524157201         1.000000
# 2760172       False      failed        1478980839         1.000000
#
#                                                       urls    usd_pledged  \
# 0        {"web":{"project":"https://www.kickstarter.com...   69687.098894
# 1        {"web":{"project":"https://www.kickstarter.com...       0.000000
# 2        {"web":{"project":"https://www.kickstarter.com...      70.000000
# 3        {"web":{"project":"https://www.kickstarter.com...      35.000000
# 4        {"web":{"project":"https://www.kickstarter.com...     941.000000
# ...                                                    ...            ...
# 2760168  {"web":{"project":"https://www.kickstarter.com...  787612.730000
# 2760169  {"web":{"project":"https://www.kickstarter.com...     301.000000
# 2760170  {"web":{"project":"https://www.kickstarter.com...       0.000000
# 2760171  {"web":{"project":"https://www.kickstarter.com...    7056.200000
# 2760172  {"web":{"project":"https://www.kickstarter.com...       0.000000
#
#          usd_type  last_update_published_at  unread_messages_count  \
# 0        domestic                       NaN                    NaN
# 1        domestic                       NaN                    NaN
# 2        domestic                       NaN                    NaN
# 3        domestic                       NaN                    NaN
# 4        domestic                       NaN                    NaN
# ...           ...                       ...                    ...
# 2760168  domestic                       NaN                    NaN
# 2760169  domestic                       NaN                    NaN
# 2760170  domestic                       NaN                    NaN
# 2760171  domestic                       NaN                    NaN
# 2760172  domestic                       NaN                    NaN
#
#          unseen_activity_count
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2760168                    NaN
# 2760169                    NaN
# 2760170                    NaN
# 2760171                    NaN
# 2760172                    NaN
#
# [2760173 rows x 41 columns]

# %%
data = data.drop_duplicates()
data
# Out:
#          backers_count                                              blurb  \
# 0                  598  Unique Matte finish, 3D print filament that re...
# 1                    0  My wife is pregnant and I promised my toddler ...
# 2                    3  Salty Dawg Customs is a small woodworking shop...
# 3                    3  Spread love into everyone's life with our vari...
# 4                   27  Wooden kazoos that are both very dynamic, and ...
# ...                ...                                                ...
# 2760168           2246  A framed high-definition screen and integrated...
# 2760169              3  We want to develop a smaller, electrically and...
# 2760170              0  A few die hard nfl fans on the wrong side of t...
# 2760171            242  Publicación digital del "Calendario Irresistib...
# 2760172              0  Fun and safe tire playground, custom built by ...
#
#                                                   category  \
# 0        {"id":331,"name":"3D Printing","slug":"technol...
# 1        {"id":356,"name":"Woodworking","slug":"crafts/...
# 2        {"id":356,"name":"Woodworking","slug":"crafts/...
# 3        {"id":54,"name":"Mixed Media","slug":"art/mixe...
# 4        {"id":356,"name":"Woodworking","slug":"crafts/...
# ...                                                    ...
# 2760168  {"id":52,"name":"Hardware","slug":"technology/...
# 2760169  {"id":52,"name":"Hardware","slug":"technology/...
# 2760170  {"id":239,"name":"Radio & Podcasts","slug":"pu...
# 2760171  {"id":325,"name":"Calendars","slug":"publishin...
# 2760172  {"id":258,"name":"Architecture","slug":"design...
#
#          converted_pledged_amount country country_displayable_name  \
# 0                         69661.0      GB       the United Kingdom
# 1                             0.0      US        the United States
# 2                            70.0      US        the United States
# 3                            35.0      US        the United States
# 4                           941.0      US        the United States
# ...                           ...     ...                      ...
# 2760168                  787612.0      US        the United States
# 2760169                     301.0      US        the United States
# 2760170                       0.0      GB       the United Kingdom
# 2760171                    7056.0      US        the United States
# 2760172                       0.0      US        the United States
#
#          created_at                                            creator  \
# 0        1474531768  {"id":73000579,"name":"Steelmans","slug":"stee...
# 1        1405638255  {"id":1119516683,"name":"Justin Haas","is_regi...
# 2        1435757008  {"id":889446413,"name":"Kevin Hart","is_regist...
# 3        1438118556  {"id":2112235325,"name":"Heather Johnson (dele...
# 4        1507246349  {"id":841853400,"name":"Leo Debevc","is_regist...
# ...             ...                                                ...
# 2760168  1398954860  {"id":1630737886,"name":"Electric Objects","sl...
# 2760169  1547491873  {"id":544645699,"name":"Bret Raymis","slug":"p...
# 2760170  1402351719  {"id":1020137667,"name":"Marc Beaton (deleted)...
# 2760171  1518734218  {"id":873433688,"name":"Rubén Jungbluth","is_r...
# 2760172  1477336137  {"id":575570128,"name":"Erin Stodolak","is_reg...
#
#         currency currency_symbol  currency_trailing_code current_currency  \
# 0            GBP               £                   False              USD
# 1            USD               $                    True              USD
# 2            USD               $                    True              USD
# 3            USD               $                    True              USD
# 4            USD               $                    True              USD
# ...          ...             ...                     ...              ...
# 2760168      USD               $                    True              USD
# 2760169      USD               $                    True              USD
# 2760170      GBP               £                   False              USD
# 2760171      USD               $                    True              USD
# 2760172      USD               $                    True              USD
#
#            deadline  disable_communication friends   fx_rate      goal  \
# 0        1496851276                  False     NaN  1.291356    9000.0
# 1        1409178684                  False     NaN  1.000000     500.0
# 2        1438782247                  False     NaN  1.000000    1900.0
# 3        1441581323                  False     NaN  1.000000     100.0
# 4        1509875776                  False     NaN  1.000000    2500.0
# ...             ...                    ...     ...       ...       ...
# 2760168  1407422151                  False     NaN  1.000000   25000.0
# 2760169  1575183540                  False     NaN  1.000000  500000.0
# 2760170  1403640082                  False     NaN  1.291356     600.0
# 2760171  1524157200                  False     NaN  1.000000   35000.0
# 2760172  1478980838                  False     NaN  1.000000     400.0
#
#                  id is_backing  is_starrable is_starred  launched_at  \
# 0        1424538693        NaN         False        NaN   1493827276
# 1         442780559        NaN         False        NaN   1406586715
# 2         387878803        NaN         False        NaN   1436190247
# 3         697381509        NaN         False        NaN   1438989323
# 4        1961865232        NaN         False        NaN   1507280176
# ...             ...        ...           ...        ...          ...
# 2760168   502128093        NaN         False        NaN   1404830151
# 2760169   267581260        NaN         False        NaN   1572727216
# 2760170  1893715389        NaN         False        NaN   1402430482
# 2760171  1120063367        NaN         False        NaN   1519072257
# 2760172  1866136332        NaN         False        NaN   1477422038
#
#                                                   location  \
# 0        {"id":12602144,"name":"Leicestershire","slug":...
# 1        {"id":2442327,"name":"Louisville","slug":"loui...
# 2        {"id":2380358,"name":"Cincinnati","slug":"cinc...
# 3        {"id":2458386,"name":"New Hartford","slug":"ne...
# 4        {"id":2356724,"name":"Ashtabula","slug":"ashta...
# ...                                                    ...
# 2760168  {"id":2459115,"name":"New York","slug":"new-yo...
# 2760169  {"id":2357536,"name":"Austin","slug":"austin-t...
# 2760170  {"id":30079,"name":"Newcastle upon Tyne","slug...
# 2760171  {"id":2450022,"name":"Miami","slug":"miami-fl"...
# 2760172  {"id":2378695,"name":"Chattanooga","slug":"cha...
#
#                                                       name permissions  \
# 0                           MATTEFORGE : 3D Print Filament         NaN
# 1                                       The Pirate Bedroom         NaN
# 2        Salty Dawg Customs - Custom, Handmade, Quality...         NaN
# 3                                             Paper Hearts         NaN
# 4        Wooden Kazoos/Membranophones Handcrafted in Oh...         NaN
# ...                                                    ...         ...
# 2760168          Electric Objects: A Computer Made for Art         NaN
# 2760169  Very Safe, Long Life, Zinc Magnetic Particle F...         NaN
# 2760170                              firstandtenuk podcast         NaN
# 2760171  CALENDARIO LUNAR PARA IMPULSAR NEGOCIOS 2018 -...         NaN
# 2760172                               Silas's Tire Kingdom         NaN
#
#                                                      photo    pledged  \
# 0        {"key":"assets/014/106/575/cd2294e8b6ff0a4663d...   53999.00
# 1        {"key":"assets/011/791/735/bbb921a2f430dd206d4...       0.00
# 2        {"key":"assets/012/184/409/1efdd36d3efc3ee9f37...      70.00
# 3        {"key":"assets/012/210/140/abf529eaf4cbbff9f72...      35.00
# 4        {"key":"assets/018/627/297/fb4db0fe457101ddfe4...     941.00
# ...                                                    ...        ...
# 2760168  {"key":"assets/011/696/686/60d6fa9c3f544a5effd...  787612.73
# 2760169  {"key":"assets/027/037/617/24431c25c97a88c90a8...     301.00
# 2760170  {"key":"assets/011/722/335/3d4dd07177d8a1941ab...       0.00
# 2760171  {"key":"assets/020/250/738/357280b472e7a9b848f...    7056.20
# 2760172  {"key":"assets/014/243/468/c92c27930d8bf7a0221...       0.00
#
#                                                    profile  \
# 0        {"id":2689913,"project_id":2689913,"state":"ac...
# 1        {"id":1198148,"project_id":1198148,"state":"in...
# 2        {"id":1991449,"project_id":1991449,"state":"in...
# 3        {"id":2039195,"project_id":2039195,"state":"in...
# 4        {"id":3171342,"project_id":3171342,"state":"in...
# ...                                                    ...
# 2760168  {"id":1002799,"project_id":1002799,"state":"ac...
# 2760169  {"id":3580581,"project_id":3580581,"state":"in...
# 2760170  {"id":1061477,"project_id":1061477,"state":"in...
# 2760171  {"id":3311397,"project_id":3311397,"state":"in...
# 2760172  {"id":2732072,"project_id":2732072,"state":"in...
#
#                                                       slug  \
# 0                             matteforge-3d-print-filament
# 1                                       the-pirate-bedroom
# 2        salty-dawg-customs-custom-handmade-quality-fur...
# 3                                             paper-hearts
# 4        wooden-kazoos-membranophones-handcrafted-in-oh...
# ...                                                    ...
# 2760168           electric-objects-a-computer-made-for-art
# 2760169  very-safe-long-life-zinc-magnetic-particle-flo...
# 2760170                              firstandtenuk-podcast
# 2760171  calendario-lunar-para-impulsar-negocios-2018-2019
# 2760172                                silass-tire-kingdom
#
#                                                 source_url  spotlight  \
# 0        https://www.kickstarter.com/discover/categorie...       True
# 1        https://www.kickstarter.com/discover/categorie...      False
# 2        https://www.kickstarter.com/discover/categorie...      False
# 3        https://www.kickstarter.com/discover/categorie...      False
# 4        https://www.kickstarter.com/discover/categorie...      False
# ...                                                    ...        ...
# 2760168  https://www.kickstarter.com/discover/categorie...       True
# 2760169  https://www.kickstarter.com/discover/categorie...      False
# 2760170  https://www.kickstarter.com/discover/categorie...      False
# 2760171  https://www.kickstarter.com/discover/categorie...      False
# 2760172  https://www.kickstarter.com/discover/categorie...      False
#
#          staff_pick       state  state_changed_at  static_usd_rate  \
# 0             False  successful        1496851277         1.290526
# 1             False      failed        1409178684         1.000000
# 2             False      failed        1438782247         1.000000
# 3             False      failed        1441581323         1.000000
# 4             False      failed        1509875777         1.000000
# ...             ...         ...               ...              ...
# 2760168        True  successful        1407422151         1.000000
# 2760169       False      failed        1575183540         1.000000
# 2760170       False      failed        1403640082         1.680602
# 2760171       False      failed        1524157201         1.000000
# 2760172       False      failed        1478980839         1.000000
#
#                                                       urls    usd_pledged  \
# 0        {"web":{"project":"https://www.kickstarter.com...   69687.098894
# 1        {"web":{"project":"https://www.kickstarter.com...       0.000000
# 2        {"web":{"project":"https://www.kickstarter.com...      70.000000
# 3        {"web":{"project":"https://www.kickstarter.com...      35.000000
# 4        {"web":{"project":"https://www.kickstarter.com...     941.000000
# ...                                                    ...            ...
# 2760168  {"web":{"project":"https://www.kickstarter.com...  787612.730000
# 2760169  {"web":{"project":"https://www.kickstarter.com...     301.000000
# 2760170  {"web":{"project":"https://www.kickstarter.com...       0.000000
# 2760171  {"web":{"project":"https://www.kickstarter.com...    7056.200000
# 2760172  {"web":{"project":"https://www.kickstarter.com...       0.000000
#
#          usd_type  last_update_published_at  unread_messages_count  \
# 0        domestic                       NaN                    NaN
# 1        domestic                       NaN                    NaN
# 2        domestic                       NaN                    NaN
# 3        domestic                       NaN                    NaN
# 4        domestic                       NaN                    NaN
# ...           ...                       ...                    ...
# 2760168  domestic                       NaN                    NaN
# 2760169  domestic                       NaN                    NaN
# 2760170  domestic                       NaN                    NaN
# 2760171  domestic                       NaN                    NaN
# 2760172  domestic                       NaN                    NaN
#
#          unseen_activity_count
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2760168                    NaN
# 2760169                    NaN
# 2760170                    NaN
# 2760171                    NaN
# 2760172                    NaN
#
# [2754215 rows x 41 columns]

# %%
data = data.sort_values('id', ascending=False)
data = data.drop_duplicates(subset='id', keep='first')
data
# Out:
#          backers_count                                              blurb  \
# 706990            2076  COLD, FRESH, & CARBONATED wherever you go! Cas...
# 919192               0  Would like to be able to photograph dream wedd...
# 1612079             53  MOMENTS OF INSIGHT is a project consisting of ...
# 663754             181  Choose your heroes wisely. Ark Worlds is a 2 p...
# 2586228             52  Growing fish and produce year round in the "Po...
# ...                ...                                                ...
# 1235403             42  Taste Makers is a socially conscious brand tha...
# 243430              18  A sanctuary for humans and felines alike! Come...
# 1623086             11  My work is performance based but I branch out ...
# 1750189              4  Raising money to help my grandmother recover f...
# 789572               2  A skin care line that is ECO-friendly, made wi...
#
#                                                   category  \
# 706990   {"id":307,"name":"Drinks","slug":"food/drinks"...
# 919192   {"id":276,"name":"Fine Art","slug":"photograph...
# 1612079  {"id":20,"name":"Conceptual Art","slug":"art/c...
# 663754   {"id":34,"name":"Tabletop Games","slug":"games...
# 2586228  {"id":305,"name":"Community Gardens","slug":"f...
# ...                                                    ...
# 1235403  {"id":269,"name":"Ready-to-wear","slug":"fashi...
# 243430   {"id":314,"name":"Spaces","slug":"food/spaces"...
# 1623086  {"id":24,"name":"Performance Art","slug":"art/...
# 1750189  {"id":44,"name":"World Music","slug":"music/wo...
# 789572   {"id":9,"name":"Fashion","slug":"fashion","pos...
#
#          converted_pledged_amount country country_displayable_name  \
# 706990                   304142.0      US        the United States
# 919192                        0.0      CA                   Canada
# 1612079                   18758.0      US        the United States
# 663754                     5026.0      US        the United States
# 2586228                    2460.0      CA                   Canada
# ...                           ...     ...                      ...
# 1235403                    2158.0      CA                   Canada
# 243430                      776.0      US        the United States
# 1623086                     262.0      GB       the United Kingdom
# 1750189                      62.0      US        the United States
# 789572                        2.0      US        the United States
#
#          created_at                                            creator  \
# 706990   1417200147  {"id":584321487,"name":"Drink Tanks","is_regis...
# 919192   1404849038  {"id":667466823,"name":"Laura","is_registered"...
# 1612079  1303753700  {"id":1743305220,"name":"Chaucer Silverson","i...
# 663754   1569172307  {"id":197765453,"name":"Unpossible Game Labs",...
# 2586228  1419960769  {"id":1810768137,"name":"Earl Decker","is_regi...
# ...             ...                                                ...
# 1235403  1426394434  {"id":1827655104,"name":"Taste Makers By Trish...
# 243430   1445787145  {"id":920978851,"name":"Tori","is_registered":...
# 1623086  1428415625  {"id":923770533,"name":"Fiona Powell","is_regi...
# 1750189  1476879198  {"id":1501687606,"name":"Devan Porter","is_reg...
# 789572   1578320345  {"id":866332793,"name":"Joseph Micacchione","s...
#
#         currency currency_symbol  currency_trailing_code current_currency  \
# 706990       USD               $                    True              USD
# 919192       CAD               $                    True              USD
# 1612079      USD               $                    True              USD
# 663754       USD               $                    True              USD
# 2586228      CAD               $                    True              USD
# ...          ...             ...                     ...              ...
# 1235403      CAD               $                    True              USD
# 243430       USD               $                    True              USD
# 1623086      GBP               £                   False              USD
# 1750189      USD               $                    True              USD
# 789572       USD               $                    True              USD
#
#            deadline  disable_communication friends   fx_rate      goal  \
# 706990   1428631200                  False     NaN  1.000000   75000.0
# 919192   1406215380                  False     NaN  0.765842    1500.0
# 1612079  1312432200                  False     NaN  1.000000   18000.0
# 663754   1584628375                  False     NaN  1.000000     500.0
# 2586228  1423675583                  False     NaN  0.737199  243000.0
# ...             ...                    ...     ...       ...       ...
# 1235403  1438280891                  False     NaN  0.709285   18000.0
# 243430   1448555133                  False     NaN  1.000000   20000.0
# 1623086  1430946000                  False     NaN  1.295882     150.0
# 1750189  1479479560                  False     NaN  1.000000   15000.0
# 789572   1583524338                  False     NaN  1.000000   10000.0
#
#                  id is_backing  is_starrable is_starred  launched_at  \
# 706990   2147476221        NaN         False        NaN   1425309278
# 919192   2147466649        NaN         False        NaN   1405104965
# 1612079  2147460119        NaN         False        NaN   1308943755
# 663754   2147450956        NaN         False        NaN   1582039992
# 2586228  2147437278        NaN         False        NaN   1420219583
# ...             ...        ...           ...        ...          ...
# 1235403       33867        NaN         False        NaN   1434392891
# 243430        24380        NaN         False        NaN   1445959533
# 1623086       21109        NaN         False        NaN   1428446264
# 1750189       18520        NaN         False        NaN   1476883960
# 789572         2941        NaN          True        NaN   1578340338
#
#                                                   location  \
# 706990   {"id":2362495,"name":"Bend","slug":"bend-or","...
# 919192   {"id":4177,"name":"Halifax","slug":"halifax-ca...
# 1612079  {"id":2367749,"name":"Bozeman","slug":"bozeman...
# 663754   {"id":12589335,"name":"Brooklyn","slug":"brook...
# 2586228  {"id":23403257,"name":"Churchill","slug":"chur...
# ...                                                    ...
# 1235403  {"id":9807,"name":"Vancouver","slug":"vancouve...
# 243430   {"id":12784759,"name":"61704","slug":null,"sho...
# 1623086  {"id":18637,"name":"Dundee","slug":"dundee-gb"...
# 1750189  {"id":2381475,"name":"Cleveland","slug":"cleve...
# 789572   {"id":2357024,"name":"Atlanta","slug":"atlanta...
#
#                                                       name permissions  \
# 706990   DrinkTanks Offers the World's Largest Growler ...         NaN
# 919192                               Dream Wedding Photo's         NaN
# 1612079                                 Moments of Insight         NaN
# 663754                          Ark Worlds: MOBA Card Game         NaN
# 2586228    Project Churchill - Food Security in the North!         NaN
# ...                                                    ...         ...
# 1235403                            TASTE MAKERS BY TRISH P         NaN
# 243430   Puss N' Books: A relaxing cat cafe and bookstore.         NaN
# 1623086                                               Meta         NaN
# 1750189                                 Grandma's are Life         NaN
# 789572                            Organic Beauty Skin Care         NaN
#
#                                                      photo   pledged  \
# 706990   {"key":"assets/011/958/733/56e89036c475988ad5f...  304142.0
# 919192   {"key":"assets/011/754/944/414c77240cb91e77952...       0.0
# 1612079  {"key":"assets/011/283/875/f7977538eeadd6cefaa...   18758.0
# 663754   {"key":"assets/028/314/633/7bc3b72e677e18d4ac8...    5026.0
# 2586228  {"key":"assets/011/985/887/b0cfe47ebedbad8f381...    3091.0
# ...                                                    ...       ...
# 1235403  {"key":"assets/012/069/475/8acca15eaf286348e89...    2798.0
# 243430   {"key":"assets/012/288/845/06e1a48097ecbb3d5cb...     776.0
# 1623086  {"key":"assets/012/099/812/be794dff82e4a678024...     173.0
# 1750189  {"key":"assets/014/175/220/334630c3d0b5814d022...      62.0
# 789572   {"key":"assets/027/670/690/fe5b6aaecf5571d6b47...       2.0
#
#                                                    profile  \
# 706990   {"id":1543801,"project_id":1543801,"state":"ac...
# 919192   {"id":1127857,"project_id":1127857,"state":"in...
# 1612079  {"id":32025,"project_id":32025,"state":"inacti...
# 663754   {"id":3818288,"project_id":3818288,"state":"ac...
# 2586228  {"id":1601747,"project_id":1601747,"state":"in...
# ...                                                    ...
# 1235403  {"id":1770331,"project_id":1770331,"state":"in...
# 243430   {"id":2192472,"project_id":2192472,"state":"in...
# 1623086  {"id":1826522,"project_id":1826522,"state":"in...
# 1750189  {"id":2725234,"project_id":2725234,"state":"in...
# 789572   {"id":3902284,"project_id":3902284,"state":"in...
#
#                                                       slug  \
# 706990   drinktanks-offers-the-worlds-largest-growler-a...
# 919192                                dream-wedding-photos
# 1612079                                 moments-of-insight
# 663754                           ark-worlds-moba-card-game
# 2586228                                  project-churchill
# ...                                                    ...
# 1235403                            taste-makers-by-trish-p
# 243430      puss-n-books-a-relaxing-cat-cafe-and-bookstore
# 1623086                                               meta
# 1750189                                  grandmas-are-life
# 789572                            organic-beauty-skin-care
#
#                                                 source_url  spotlight  \
# 706990   https://www.kickstarter.com/discover/categorie...       True
# 919192   https://www.kickstarter.com/discover/categorie...      False
# 1612079  https://www.kickstarter.com/discover/categorie...       True
# 663754   https://www.kickstarter.com/discover/categorie...       True
# 2586228  https://www.kickstarter.com/discover/categorie...      False
# ...                                                    ...        ...
# 1235403  https://www.kickstarter.com/discover/categorie...      False
# 243430   https://www.kickstarter.com/discover/categorie...      False
# 1623086  https://www.kickstarter.com/discover/categorie...       True
# 1750189  https://www.kickstarter.com/discover/categorie...      False
# 789572   https://www.kickstarter.com/discover/categorie...      False
#
#          staff_pick       state  state_changed_at  static_usd_rate  \
# 706990        False  successful        1428631231         1.000000
# 919192        False      failed        1406215380         0.938523
# 1612079        True  successful        1312432269         1.000000
# 663754         True  successful        1584628375         1.000000
# 2586228       False      failed        1423675583         0.860877
# ...             ...         ...               ...              ...
# 1235403        True      failed        1438280891         0.811910
# 243430        False      failed        1448555133         1.000000
# 1623086       False  successful        1430946012         1.491538
# 1750189       False      failed        1479479560         1.000000
# 789572        False        live        1578340338         1.000000
#
#                                                       urls    usd_pledged  \
# 706990   {"web":{"project":"https://www.kickstarter.com...  304142.000000
# 919192   {"web":{"project":"https://www.kickstarter.com...       0.000000
# 1612079  {"web":{"project":"https://www.kickstarter.com...   18758.000000
# 663754   {"web":{"project":"https://www.kickstarter.com...    5026.000000
# 2586228  {"web":{"project":"https://www.kickstarter.com...    2660.971116
# ...                                                    ...            ...
# 1235403  {"web":{"project":"https://www.kickstarter.com...    2271.723453
# 243430   {"web":{"project":"https://www.kickstarter.com...     776.000000
# 1623086  {"web":{"project":"https://www.kickstarter.com...     258.036032
# 1750189  {"web":{"project":"https://www.kickstarter.com...      62.000000
# 789572   {"web":{"project":"https://www.kickstarter.com...       2.000000
#
#               usd_type  last_update_published_at  unread_messages_count  \
# 706990        domestic                       NaN                    NaN
# 919192   international                       NaN                    NaN
# 1612079       domestic                       NaN                    NaN
# 663754        domestic                       NaN                    NaN
# 2586228       domestic                       NaN                    NaN
# ...                ...                       ...                    ...
# 1235403       domestic                       NaN                    NaN
# 243430        domestic                       NaN                    NaN
# 1623086       domestic                       NaN                    NaN
# 1750189       domestic                       NaN                    NaN
# 789572        domestic                       NaN                    NaN
#
#          unseen_activity_count
# 706990                     NaN
# 919192                     NaN
# 1612079                    NaN
# 663754                     NaN
# 2586228                    NaN
# ...                        ...
# 1235403                    NaN
# 243430                     NaN
# 1623086                    NaN
# 1750189                    NaN
# 789572                     NaN
#
# [222555 rows x 41 columns]

# %%
# goal was still in local currency. did conversion and dropper original
goal_convert = data['fx_rate']*data['goal']
data['goal_convert'] = goal_convert 
data = data.drop(columns=['goal'])

# %%
data
# Out:
#          backers_count                                              blurb  \
# 706990            2076  COLD, FRESH, & CARBONATED wherever you go! Cas...
# 919192               0  Would like to be able to photograph dream wedd...
# 1612079             53  MOMENTS OF INSIGHT is a project consisting of ...
# 663754             181  Choose your heroes wisely. Ark Worlds is a 2 p...
# 2586228             52  Growing fish and produce year round in the "Po...
# ...                ...                                                ...
# 1235403             42  Taste Makers is a socially conscious brand tha...
# 243430              18  A sanctuary for humans and felines alike! Come...
# 1623086             11  My work is performance based but I branch out ...
# 1750189              4  Raising money to help my grandmother recover f...
# 789572               2  A skin care line that is ECO-friendly, made wi...
#
#                                                   category  \
# 706990   {"id":307,"name":"Drinks","slug":"food/drinks"...
# 919192   {"id":276,"name":"Fine Art","slug":"photograph...
# 1612079  {"id":20,"name":"Conceptual Art","slug":"art/c...
# 663754   {"id":34,"name":"Tabletop Games","slug":"games...
# 2586228  {"id":305,"name":"Community Gardens","slug":"f...
# ...                                                    ...
# 1235403  {"id":269,"name":"Ready-to-wear","slug":"fashi...
# 243430   {"id":314,"name":"Spaces","slug":"food/spaces"...
# 1623086  {"id":24,"name":"Performance Art","slug":"art/...
# 1750189  {"id":44,"name":"World Music","slug":"music/wo...
# 789572   {"id":9,"name":"Fashion","slug":"fashion","pos...
#
#          converted_pledged_amount country country_displayable_name  \
# 706990                   304142.0      US        the United States
# 919192                        0.0      CA                   Canada
# 1612079                   18758.0      US        the United States
# 663754                     5026.0      US        the United States
# 2586228                    2460.0      CA                   Canada
# ...                           ...     ...                      ...
# 1235403                    2158.0      CA                   Canada
# 243430                      776.0      US        the United States
# 1623086                     262.0      GB       the United Kingdom
# 1750189                      62.0      US        the United States
# 789572                        2.0      US        the United States
#
#          created_at                                            creator  \
# 706990   1417200147  {"id":584321487,"name":"Drink Tanks","is_regis...
# 919192   1404849038  {"id":667466823,"name":"Laura","is_registered"...
# 1612079  1303753700  {"id":1743305220,"name":"Chaucer Silverson","i...
# 663754   1569172307  {"id":197765453,"name":"Unpossible Game Labs",...
# 2586228  1419960769  {"id":1810768137,"name":"Earl Decker","is_regi...
# ...             ...                                                ...
# 1235403  1426394434  {"id":1827655104,"name":"Taste Makers By Trish...
# 243430   1445787145  {"id":920978851,"name":"Tori","is_registered":...
# 1623086  1428415625  {"id":923770533,"name":"Fiona Powell","is_regi...
# 1750189  1476879198  {"id":1501687606,"name":"Devan Porter","is_reg...
# 789572   1578320345  {"id":866332793,"name":"Joseph Micacchione","s...
#
#         currency currency_symbol  currency_trailing_code current_currency  \
# 706990       USD               $                    True              USD
# 919192       CAD               $                    True              USD
# 1612079      USD               $                    True              USD
# 663754       USD               $                    True              USD
# 2586228      CAD               $                    True              USD
# ...          ...             ...                     ...              ...
# 1235403      CAD               $                    True              USD
# 243430       USD               $                    True              USD
# 1623086      GBP               £                   False              USD
# 1750189      USD               $                    True              USD
# 789572       USD               $                    True              USD
#
#            deadline  disable_communication friends   fx_rate          id  \
# 706990   1428631200                  False     NaN  1.000000  2147476221
# 919192   1406215380                  False     NaN  0.765842  2147466649
# 1612079  1312432200                  False     NaN  1.000000  2147460119
# 663754   1584628375                  False     NaN  1.000000  2147450956
# 2586228  1423675583                  False     NaN  0.737199  2147437278
# ...             ...                    ...     ...       ...         ...
# 1235403  1438280891                  False     NaN  0.709285       33867
# 243430   1448555133                  False     NaN  1.000000       24380
# 1623086  1430946000                  False     NaN  1.295882       21109
# 1750189  1479479560                  False     NaN  1.000000       18520
# 789572   1583524338                  False     NaN  1.000000        2941
#
#         is_backing  is_starrable is_starred  launched_at  \
# 706990         NaN         False        NaN   1425309278
# 919192         NaN         False        NaN   1405104965
# 1612079        NaN         False        NaN   1308943755
# 663754         NaN         False        NaN   1582039992
# 2586228        NaN         False        NaN   1420219583
# ...            ...           ...        ...          ...
# 1235403        NaN         False        NaN   1434392891
# 243430         NaN         False        NaN   1445959533
# 1623086        NaN         False        NaN   1428446264
# 1750189        NaN         False        NaN   1476883960
# 789572         NaN          True        NaN   1578340338
#
#                                                   location  \
# 706990   {"id":2362495,"name":"Bend","slug":"bend-or","...
# 919192   {"id":4177,"name":"Halifax","slug":"halifax-ca...
# 1612079  {"id":2367749,"name":"Bozeman","slug":"bozeman...
# 663754   {"id":12589335,"name":"Brooklyn","slug":"brook...
# 2586228  {"id":23403257,"name":"Churchill","slug":"chur...
# ...                                                    ...
# 1235403  {"id":9807,"name":"Vancouver","slug":"vancouve...
# 243430   {"id":12784759,"name":"61704","slug":null,"sho...
# 1623086  {"id":18637,"name":"Dundee","slug":"dundee-gb"...
# 1750189  {"id":2381475,"name":"Cleveland","slug":"cleve...
# 789572   {"id":2357024,"name":"Atlanta","slug":"atlanta...
#
#                                                       name permissions  \
# 706990   DrinkTanks Offers the World's Largest Growler ...         NaN
# 919192                               Dream Wedding Photo's         NaN
# 1612079                                 Moments of Insight         NaN
# 663754                          Ark Worlds: MOBA Card Game         NaN
# 2586228    Project Churchill - Food Security in the North!         NaN
# ...                                                    ...         ...
# 1235403                            TASTE MAKERS BY TRISH P         NaN
# 243430   Puss N' Books: A relaxing cat cafe and bookstore.         NaN
# 1623086                                               Meta         NaN
# 1750189                                 Grandma's are Life         NaN
# 789572                            Organic Beauty Skin Care         NaN
#
#                                                      photo   pledged  \
# 706990   {"key":"assets/011/958/733/56e89036c475988ad5f...  304142.0
# 919192   {"key":"assets/011/754/944/414c77240cb91e77952...       0.0
# 1612079  {"key":"assets/011/283/875/f7977538eeadd6cefaa...   18758.0
# 663754   {"key":"assets/028/314/633/7bc3b72e677e18d4ac8...    5026.0
# 2586228  {"key":"assets/011/985/887/b0cfe47ebedbad8f381...    3091.0
# ...                                                    ...       ...
# 1235403  {"key":"assets/012/069/475/8acca15eaf286348e89...    2798.0
# 243430   {"key":"assets/012/288/845/06e1a48097ecbb3d5cb...     776.0
# 1623086  {"key":"assets/012/099/812/be794dff82e4a678024...     173.0
# 1750189  {"key":"assets/014/175/220/334630c3d0b5814d022...      62.0
# 789572   {"key":"assets/027/670/690/fe5b6aaecf5571d6b47...       2.0
#
#                                                    profile  \
# 706990   {"id":1543801,"project_id":1543801,"state":"ac...
# 919192   {"id":1127857,"project_id":1127857,"state":"in...
# 1612079  {"id":32025,"project_id":32025,"state":"inacti...
# 663754   {"id":3818288,"project_id":3818288,"state":"ac...
# 2586228  {"id":1601747,"project_id":1601747,"state":"in...
# ...                                                    ...
# 1235403  {"id":1770331,"project_id":1770331,"state":"in...
# 243430   {"id":2192472,"project_id":2192472,"state":"in...
# 1623086  {"id":1826522,"project_id":1826522,"state":"in...
# 1750189  {"id":2725234,"project_id":2725234,"state":"in...
# 789572   {"id":3902284,"project_id":3902284,"state":"in...
#
#                                                       slug  \
# 706990   drinktanks-offers-the-worlds-largest-growler-a...
# 919192                                dream-wedding-photos
# 1612079                                 moments-of-insight
# 663754                           ark-worlds-moba-card-game
# 2586228                                  project-churchill
# ...                                                    ...
# 1235403                            taste-makers-by-trish-p
# 243430      puss-n-books-a-relaxing-cat-cafe-and-bookstore
# 1623086                                               meta
# 1750189                                  grandmas-are-life
# 789572                            organic-beauty-skin-care
#
#                                                 source_url  spotlight  \
# 706990   https://www.kickstarter.com/discover/categorie...       True
# 919192   https://www.kickstarter.com/discover/categorie...      False
# 1612079  https://www.kickstarter.com/discover/categorie...       True
# 663754   https://www.kickstarter.com/discover/categorie...       True
# 2586228  https://www.kickstarter.com/discover/categorie...      False
# ...                                                    ...        ...
# 1235403  https://www.kickstarter.com/discover/categorie...      False
# 243430   https://www.kickstarter.com/discover/categorie...      False
# 1623086  https://www.kickstarter.com/discover/categorie...       True
# 1750189  https://www.kickstarter.com/discover/categorie...      False
# 789572   https://www.kickstarter.com/discover/categorie...      False
#
#          staff_pick       state  state_changed_at  static_usd_rate  \
# 706990        False  successful        1428631231         1.000000
# 919192        False      failed        1406215380         0.938523
# 1612079        True  successful        1312432269         1.000000
# 663754         True  successful        1584628375         1.000000
# 2586228       False      failed        1423675583         0.860877
# ...             ...         ...               ...              ...
# 1235403        True      failed        1438280891         0.811910
# 243430        False      failed        1448555133         1.000000
# 1623086       False  successful        1430946012         1.491538
# 1750189       False      failed        1479479560         1.000000
# 789572        False        live        1578340338         1.000000
#
#                                                       urls    usd_pledged  \
# 706990   {"web":{"project":"https://www.kickstarter.com...  304142.000000
# 919192   {"web":{"project":"https://www.kickstarter.com...       0.000000
# 1612079  {"web":{"project":"https://www.kickstarter.com...   18758.000000
# 663754   {"web":{"project":"https://www.kickstarter.com...    5026.000000
# 2586228  {"web":{"project":"https://www.kickstarter.com...    2660.971116
# ...                                                    ...            ...
# 1235403  {"web":{"project":"https://www.kickstarter.com...    2271.723453
# 243430   {"web":{"project":"https://www.kickstarter.com...     776.000000
# 1623086  {"web":{"project":"https://www.kickstarter.com...     258.036032
# 1750189  {"web":{"project":"https://www.kickstarter.com...      62.000000
# 789572   {"web":{"project":"https://www.kickstarter.com...       2.000000
#
#               usd_type  last_update_published_at  unread_messages_count  \
# 706990        domestic                       NaN                    NaN
# 919192   international                       NaN                    NaN
# 1612079       domestic                       NaN                    NaN
# 663754        domestic                       NaN                    NaN
# 2586228       domestic                       NaN                    NaN
# ...                ...                       ...                    ...
# 1235403       domestic                       NaN                    NaN
# 243430        domestic                       NaN                    NaN
# 1623086       domestic                       NaN                    NaN
# 1750189       domestic                       NaN                    NaN
# 789572        domestic                       NaN                    NaN
#
#          unseen_activity_count   goal_convert
# 706990                     NaN   75000.000000
# 919192                     NaN    1148.763315
# 1612079                    NaN   18000.000000
# 663754                     NaN     500.000000
# 2586228                    NaN  179139.466350
# ...                        ...            ...
# 1235403                    NaN   12767.134500
# 243430                     NaN   20000.000000
# 1623086                    NaN     194.382350
# 1750189                    NaN   15000.000000
# 789572                     NaN   10000.000000
#
# [222555 rows x 41 columns]

# %%
# display content of columns
data.count()
# Out:
# backers_count               222555
# blurb                       222547
# category                    222555
# converted_pledged_amount    222554
# country                     222555
# country_displayable_name    202245
# created_at                  222555
# creator                     222555
# currency                    222555
# currency_symbol             222555
# currency_trailing_code      222555
# current_currency            222555
# deadline                    222555
# disable_communication       222555
# friends                        575
# fx_rate                     222555
# id                          222555
# is_backing                     575
# is_starrable                222555
# is_starred                     575
# launched_at                 222555
# location                    222338
# name                        222554
# permissions                    575
# photo                       222555
# pledged                     222555
# profile                     222555
# slug                        222555
# source_url                  222555
# spotlight                   222555
# staff_pick                  222555
# state                       222555
# state_changed_at            222555
# static_usd_rate             222555
# urls                        222555
# usd_pledged                 222554
# usd_type                    221842
# last_update_published_at         0
# unread_messages_count            0
# unseen_activity_count            0
# goal_convert                222555
# dtype: int64

# %% [markdown]
# The dataset contains projects added to Kickstarter between 22 April 2009 and 16 September 2020

# %%
len(data)
# Out:
# 222555

# %%
# dropping duplicates
clean = data.drop_duplicates()

# %%
# looking for duplicates
len(clean)
# Out:
# 222555

# %% [markdown]
# # Column content:
# - backers_count - count of the backers
# - blurb - description of project
# - category - category and sub-category of the kickstarter project
# - converted_pledged_amount - amount pledged converted to USD
# - country - source of project
# - country_displayable_name - displayed name
# - created_at - date and time when created
# - creator - creator of project and some more info
# - currency - original currency
# - currency_symbol - original currency symbol
# - current_trailing_code - ?
# - current_currency - converted USD currency
# - deadline - date and time deadline
# - disable_communication - whether owner disabled communication with backers
# - friends - if people are friends? not sure. mainly empty
# - fx_rate - forex rate from original currency
# - goal - goal
# - id - id number
# - is_backing - ?
# - is_starrable - is this project able to be favorited by someone?
# - is_starred - is it favorited by someone
# - launched_at - launch date
# - location - location
# - name - name
# - permissions - ? mainly empty
# - photo - project photo
# - pledged - amount pledged
# - profile - project profile
# - slug - name of the project
# - source_url - url
# - spotlight - advertised by kickstarter after successful
# - staff_pick - chosed by staff so it gets more coverage
# - state - whether a project was successful, failed, canceled, suspending or still live
# - state_changed_at - date and time when project's status was changed. same as deadline for successful and failed
# - static_usd_rate - conversion rate between the original currency and USD
# - urls - url
# - usd_pledged - amount pledged in USD
# - usd_type - domestic or international
# - last_update_published_at - last update time
# - unread_messages_count - count of unread messages
# - unseen_activity_count - count of unseen activity

# %%
# dropping columns with small no-null values
clean.drop(['friends', 'is_backing', 'is_starred', 'permissions','last_update_published_at','unread_messages_count','unseen_activity_count'], axis=1, inplace=True)

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222555 entries, 706990 to 789572
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   backers_count             222555 non-null  int64
#  1   blurb                     222547 non-null  object
#  2   category                  222555 non-null  object
#  3   converted_pledged_amount  222554 non-null  float64
#  4   country                   222555 non-null  object
#  5   country_displayable_name  202245 non-null  object
#  6   created_at                222555 non-null  int64
#  7   creator                   222555 non-null  object
#  8   currency                  222555 non-null  object
#  9   currency_symbol           222555 non-null  object
#  10  currency_trailing_code    222555 non-null  bool
#  11  current_currency          222555 non-null  object
#  12  deadline                  222555 non-null  int64
#  13  disable_communication     222555 non-null  bool
#  14  fx_rate                   222555 non-null  float64
#  15  id                        222555 non-null  int64
#  16  is_starrable              222555 non-null  bool
#  17  launched_at               222555 non-null  int64
#  18  location                  222338 non-null  object
#  19  name                      222554 non-null  object
#  20  photo                     222555 non-null  object
#  21  pledged                   222555 non-null  float64
#  22  profile                   222555 non-null  object
#  23  slug                      222555 non-null  object
#  24  source_url                222555 non-null  object
#  25  spotlight                 222555 non-null  bool
#  26  staff_pick                222555 non-null  bool
#  27  state                     222555 non-null  object
#  28  state_changed_at          222555 non-null  int64
#  29  static_usd_rate           222555 non-null  float64
#  30  urls                      222555 non-null  object
#  31  usd_pledged               222554 non-null  float64
#  32  usd_type                  221842 non-null  object
#  33  goal_convert              222555 non-null  float64
# dtypes: bool(5), float64(6), int64(6), object(17)
# memory usage: 52.0+ MB

# %% [markdown]
# dropping irrelevant columns listed below as well
# - converted_pledged_amount - same as usd_pledged
# - country - same as country_displayed_name
# - creator - irrelevant
# - currency - irrelvant as converted
# - currency_symbol - irrelevant
# - currency_trailing_code - irrelevant
# - currenct_currency - irrelevant as it has converted
# - disable_communication - almost all the same
# - fx_rate - irrelevant. info in USD_pledged
# - is_starrable - irrelevant
# - name - irrelevant
# - photo - irrelevant
# - profile -irrelevant
# - slug -same as name. irrelevant
# - source_url- irrelevant
# - spotlight - irrelevant as it is only for projects that succeeded. will skew results
# - state_changed_at - irrelevant
# - static_usd_rate -irrelevant
# - urls - irrelevant
# - usd_type - irrelevant

# %%
# Dropping useless columns
clean.drop(['converted_pledged_amount', 'country', 'creator', 'currency', 'currency_symbol', 'currency_trailing_code','disable_communication', 'fx_rate', 'is_starrable', 'name', 'photo', 'profile', 'slug', 'source_url', 'spotlight', 'state_changed_at', 'static_usd_rate','urls', 'usd_type', 'current_currency'], axis=1, inplace=True)

# %%
clean.head()
# Out:
#          backers_count                                              blurb  \
# 706990            2076  COLD, FRESH, & CARBONATED wherever you go! Cas...
# 919192               0  Would like to be able to photograph dream wedd...
# 1612079             53  MOMENTS OF INSIGHT is a project consisting of ...
# 663754             181  Choose your heroes wisely. Ark Worlds is a 2 p...
# 2586228             52  Growing fish and produce year round in the "Po...
#
#                                                   category  \
# 706990   {"id":307,"name":"Drinks","slug":"food/drinks"...
# 919192   {"id":276,"name":"Fine Art","slug":"photograph...
# 1612079  {"id":20,"name":"Conceptual Art","slug":"art/c...
# 663754   {"id":34,"name":"Tabletop Games","slug":"games...
# 2586228  {"id":305,"name":"Community Gardens","slug":"f...
#
#         country_displayable_name  created_at    deadline          id  \
# 706990         the United States  1417200147  1428631200  2147476221
# 919192                    Canada  1404849038  1406215380  2147466649
# 1612079        the United States  1303753700  1312432200  2147460119
# 663754         the United States  1569172307  1584628375  2147450956
# 2586228                   Canada  1419960769  1423675583  2147437278
#
#          launched_at                                           location  \
# 706990    1425309278  {"id":2362495,"name":"Bend","slug":"bend-or","...
# 919192    1405104965  {"id":4177,"name":"Halifax","slug":"halifax-ca...
# 1612079   1308943755  {"id":2367749,"name":"Bozeman","slug":"bozeman...
# 663754    1582039992  {"id":12589335,"name":"Brooklyn","slug":"brook...
# 2586228   1420219583  {"id":23403257,"name":"Churchill","slug":"chur...
#
#           pledged  staff_pick       state    usd_pledged   goal_convert
# 706990   304142.0       False  successful  304142.000000   75000.000000
# 919192        0.0       False      failed       0.000000    1148.763315
# 1612079   18758.0        True  successful   18758.000000   18000.000000
# 663754     5026.0        True  successful    5026.000000     500.000000
# 2586228    3091.0       False      failed    2660.971116  179139.466350

# %% [markdown]
# need to convert unix times to standard

# %%
# Converting dates from unix to datetime
unix_convert = ['created_at', 'deadline', 'launched_at']
for x in unix_convert:
    clean[x] = pd.to_datetime(clean[x], origin='unix', unit='s')

# %%
clean.head()
# Out:
#          backers_count                                              blurb  \
# 706990            2076  COLD, FRESH, & CARBONATED wherever you go! Cas...
# 919192               0  Would like to be able to photograph dream wedd...
# 1612079             53  MOMENTS OF INSIGHT is a project consisting of ...
# 663754             181  Choose your heroes wisely. Ark Worlds is a 2 p...
# 2586228             52  Growing fish and produce year round in the "Po...
#
#                                                   category  \
# 706990   {"id":307,"name":"Drinks","slug":"food/drinks"...
# 919192   {"id":276,"name":"Fine Art","slug":"photograph...
# 1612079  {"id":20,"name":"Conceptual Art","slug":"art/c...
# 663754   {"id":34,"name":"Tabletop Games","slug":"games...
# 2586228  {"id":305,"name":"Community Gardens","slug":"f...
#
#         country_displayable_name          created_at            deadline  \
# 706990         the United States 2014-11-28 18:42:27 2015-04-10 02:00:00
# 919192                    Canada 2014-07-08 19:50:38 2014-07-24 15:23:00
# 1612079        the United States 2011-04-25 17:48:20 2011-08-04 04:30:00
# 663754         the United States 2019-09-22 17:11:47 2020-03-19 14:32:55
# 2586228                   Canada 2014-12-30 17:32:49 2015-02-11 17:26:23
#
#                  id         launched_at  \
# 706990   2147476221 2015-03-02 15:14:38
# 919192   2147466649 2014-07-11 18:56:05
# 1612079  2147460119 2011-06-24 19:29:15
# 663754   2147450956 2020-02-18 15:33:12
# 2586228  2147437278 2015-01-02 17:26:23
#
#                                                   location   pledged  \
# 706990   {"id":2362495,"name":"Bend","slug":"bend-or","...  304142.0
# 919192   {"id":4177,"name":"Halifax","slug":"halifax-ca...       0.0
# 1612079  {"id":2367749,"name":"Bozeman","slug":"bozeman...   18758.0
# 663754   {"id":12589335,"name":"Brooklyn","slug":"brook...    5026.0
# 2586228  {"id":23403257,"name":"Churchill","slug":"chur...    3091.0
#
#          staff_pick       state    usd_pledged   goal_convert
# 706990        False  successful  304142.000000   75000.000000
# 919192        False      failed       0.000000    1148.763315
# 1612079        True  successful   18758.000000   18000.000000
# 663754         True  successful    5026.000000     500.000000
# 2586228       False      failed    2660.971116  179139.466350

# %%
# Extract sub-category section from category
f = lambda x: x['category'].split('/')[1].split('","position')[0]
clean['sub_category'] = clean.apply(f, axis=1)

#extract and replace
f = lambda x: x['category'].split('"slug":"')[1].split('/')[0]
clean['category'] = clean.apply(f, axis=1)
f = lambda x: x['category'].split('","position"')[0] 
clean['category'] = clean.apply(f, axis=1)

# %%
clean.head()
# Out:
#          backers_count                                              blurb  \
# 706990            2076  COLD, FRESH, & CARBONATED wherever you go! Cas...
# 919192               0  Would like to be able to photograph dream wedd...
# 1612079             53  MOMENTS OF INSIGHT is a project consisting of ...
# 663754             181  Choose your heroes wisely. Ark Worlds is a 2 p...
# 2586228             52  Growing fish and produce year round in the "Po...
#
#             category country_displayable_name          created_at  \
# 706990          food        the United States 2014-11-28 18:42:27
# 919192   photography                   Canada 2014-07-08 19:50:38
# 1612079          art        the United States 2011-04-25 17:48:20
# 663754         games        the United States 2019-09-22 17:11:47
# 2586228         food                   Canada 2014-12-30 17:32:49
#
#                    deadline          id         launched_at  \
# 706990  2015-04-10 02:00:00  2147476221 2015-03-02 15:14:38
# 919192  2014-07-24 15:23:00  2147466649 2014-07-11 18:56:05
# 1612079 2011-08-04 04:30:00  2147460119 2011-06-24 19:29:15
# 663754  2020-03-19 14:32:55  2147450956 2020-02-18 15:33:12
# 2586228 2015-02-11 17:26:23  2147437278 2015-01-02 17:26:23
#
#                                                   location   pledged  \
# 706990   {"id":2362495,"name":"Bend","slug":"bend-or","...  304142.0
# 919192   {"id":4177,"name":"Halifax","slug":"halifax-ca...       0.0
# 1612079  {"id":2367749,"name":"Bozeman","slug":"bozeman...   18758.0
# 663754   {"id":12589335,"name":"Brooklyn","slug":"brook...    5026.0
# 2586228  {"id":23403257,"name":"Churchill","slug":"chur...    3091.0
#
#          staff_pick       state    usd_pledged   goal_convert  \
# 706990        False  successful  304142.000000   75000.000000
# 919192        False      failed       0.000000    1148.763315
# 1612079        True  successful   18758.000000   18000.000000
# 663754         True  successful    5026.000000     500.000000
# 2586228       False      failed    2660.971116  179139.466350
#
#               sub_category
# 706990              drinks
# 919192            fine art
# 1612079     conceptual art
# 663754      tabletop games
# 2586228  community gardens

# %%
# Counting the number of unique countries
clean.country_displayable_name.unique()
# Out:
# array(['the United States', 'Canada', 'Australia', nan, 'Italy',
#        'Germany', 'France', 'the United Kingdom', 'Hong Kong',
#        'New Zealand', 'Spain', 'Japan', 'the Netherlands', 'Mexico',
#        'Austria', 'Singapore', 'Switzerland', 'Ireland', 'Sweden',
#        'Belgium', 'Denmark', 'Norway', 'Luxembourg'], dtype=object)

# %%
#location column has way too many unique values, will drop

clean.drop('location', axis=1, inplace=True)

# %%
clean.head()
# Out:
#          backers_count                                              blurb  \
# 706990            2076  COLD, FRESH, & CARBONATED wherever you go! Cas...
# 919192               0  Would like to be able to photograph dream wedd...
# 1612079             53  MOMENTS OF INSIGHT is a project consisting of ...
# 663754             181  Choose your heroes wisely. Ark Worlds is a 2 p...
# 2586228             52  Growing fish and produce year round in the "Po...
#
#             category country_displayable_name          created_at  \
# 706990          food        the United States 2014-11-28 18:42:27
# 919192   photography                   Canada 2014-07-08 19:50:38
# 1612079          art        the United States 2011-04-25 17:48:20
# 663754         games        the United States 2019-09-22 17:11:47
# 2586228         food                   Canada 2014-12-30 17:32:49
#
#                    deadline          id         launched_at   pledged  \
# 706990  2015-04-10 02:00:00  2147476221 2015-03-02 15:14:38  304142.0
# 919192  2014-07-24 15:23:00  2147466649 2014-07-11 18:56:05       0.0
# 1612079 2011-08-04 04:30:00  2147460119 2011-06-24 19:29:15   18758.0
# 663754  2020-03-19 14:32:55  2147450956 2020-02-18 15:33:12    5026.0
# 2586228 2015-02-11 17:26:23  2147437278 2015-01-02 17:26:23    3091.0
#
#          staff_pick       state    usd_pledged   goal_convert  \
# 706990        False  successful  304142.000000   75000.000000
# 919192        False      failed       0.000000    1148.763315
# 1612079        True  successful   18758.000000   18000.000000
# 663754         True  successful    5026.000000     500.000000
# 2586228       False      failed    2660.971116  179139.466350
#
#               sub_category
# 706990              drinks
# 919192            fine art
# 1612079     conceptual art
# 663754      tabletop games
# 2586228  community gardens

# %% [markdown]
# blurb
# We will not be focusing on NLP for this project so we will convert this info into something relevant for us. We will look at the length of the blurbs and see if this is has any impact

# %%
# Count length of each blurb
clean['blurb_length'] = clean['blurb'].str.split().str.len()

# Drop blurb variable
clean.drop('blurb', axis=1, inplace=True)

# %%
clean.head()
# Out:
#          backers_count     category country_displayable_name  \
# 706990            2076         food        the United States
# 919192               0  photography                   Canada
# 1612079             53          art        the United States
# 663754             181        games        the United States
# 2586228             52         food                   Canada
#
#                  created_at            deadline          id  \
# 706990  2014-11-28 18:42:27 2015-04-10 02:00:00  2147476221
# 919192  2014-07-08 19:50:38 2014-07-24 15:23:00  2147466649
# 1612079 2011-04-25 17:48:20 2011-08-04 04:30:00  2147460119
# 663754  2019-09-22 17:11:47 2020-03-19 14:32:55  2147450956
# 2586228 2014-12-30 17:32:49 2015-02-11 17:26:23  2147437278
#
#                 launched_at   pledged  staff_pick       state    usd_pledged  \
# 706990  2015-03-02 15:14:38  304142.0       False  successful  304142.000000
# 919192  2014-07-11 18:56:05       0.0       False      failed       0.000000
# 1612079 2011-06-24 19:29:15   18758.0        True  successful   18758.000000
# 663754  2020-02-18 15:33:12    5026.0        True  successful    5026.000000
# 2586228 2015-01-02 17:26:23    3091.0       False      failed    2660.971116
#
#           goal_convert       sub_category  blurb_length
# 706990    75000.000000             drinks          20.0
# 919192     1148.763315           fine art          22.0
# 1612079   18000.000000     conceptual art          21.0
# 663754      500.000000     tabletop games          23.0
# 2586228  179139.466350  community gardens          18.0

# %%
#smaller filesize so everything will be quicker
clean.to_csv( "../../../final_product/data/clean_data.csv", index=False)

# %%
clean_data = pd.read_csv('../../../final_product/data/clean_data.csv')
clean_data.head()
# Out:
#    backers_count     category country_displayable_name           created_at  \
# 0           2076         food        the United States  2014-11-28 18:42:27
# 1              0  photography                   Canada  2014-07-08 19:50:38
# 2             53          art        the United States  2011-04-25 17:48:20
# 3            181        games        the United States  2019-09-22 17:11:47
# 4             52         food                   Canada  2014-12-30 17:32:49
#
#               deadline          id          launched_at   pledged  staff_pick  \
# 0  2015-04-10 02:00:00  2147476221  2015-03-02 15:14:38  304142.0       False
# 1  2014-07-24 15:23:00  2147466649  2014-07-11 18:56:05       0.0       False
# 2  2011-08-04 04:30:00  2147460119  2011-06-24 19:29:15   18758.0        True
# 3  2020-03-19 14:32:55  2147450956  2020-02-18 15:33:12    5026.0        True
# 4  2015-02-11 17:26:23  2147437278  2015-01-02 17:26:23    3091.0       False
#
#         state    usd_pledged   goal_convert       sub_category  blurb_length
# 0  successful  304142.000000   75000.000000             drinks          20.0
# 1      failed       0.000000    1148.763315           fine art          22.0
# 2  successful   18758.000000   18000.000000     conceptual art          21.0
# 3  successful    5026.000000     500.000000     tabletop games          23.0
# 4      failed    2660.971116  179139.466350  community gardens          18.0

# %%
data_clean = clean_data

# %%
#index to id
data_clean.set_index('id')
# Out:
#             backers_count     category country_displayable_name  \
# id
# 2147476221           2076         food        the United States
# 2147466649              0  photography                   Canada
# 2147460119             53          art        the United States
# 2147450956            181        games        the United States
# 2147437278             52         food                   Canada
# ...                   ...          ...                      ...
# 33867                  42      fashion                   Canada
# 24380                  18         food        the United States
# 21109                  11          art       the United Kingdom
# 18520                   4        music        the United States
# 2941                    2      fashion        the United States
#
#                      created_at             deadline          launched_at  \
# id
# 2147476221  2014-11-28 18:42:27  2015-04-10 02:00:00  2015-03-02 15:14:38
# 2147466649  2014-07-08 19:50:38  2014-07-24 15:23:00  2014-07-11 18:56:05
# 2147460119  2011-04-25 17:48:20  2011-08-04 04:30:00  2011-06-24 19:29:15
# 2147450956  2019-09-22 17:11:47  2020-03-19 14:32:55  2020-02-18 15:33:12
# 2147437278  2014-12-30 17:32:49  2015-02-11 17:26:23  2015-01-02 17:26:23
# ...                         ...                  ...                  ...
# 33867       2015-03-15 04:40:34  2015-07-30 18:28:11  2015-06-15 18:28:11
# 24380       2015-10-25 15:32:25  2015-11-26 16:25:33  2015-10-27 15:25:33
# 21109       2015-04-07 14:07:05  2015-05-06 21:00:00  2015-04-07 22:37:44
# 18520       2016-10-19 12:13:18  2016-11-18 14:32:40  2016-10-19 13:32:40
# 2941        2020-01-06 14:19:05  2020-03-06 19:52:18  2020-01-06 19:52:18
#
#              pledged  staff_pick       state    usd_pledged   goal_convert  \
# id
# 2147476221  304142.0       False  successful  304142.000000   75000.000000
# 2147466649       0.0       False      failed       0.000000    1148.763315
# 2147460119   18758.0        True  successful   18758.000000   18000.000000
# 2147450956    5026.0        True  successful    5026.000000     500.000000
# 2147437278    3091.0       False      failed    2660.971116  179139.466350
# ...              ...         ...         ...            ...            ...
# 33867         2798.0        True      failed    2271.723453   12767.134500
# 24380          776.0       False      failed     776.000000   20000.000000
# 21109          173.0       False  successful     258.036032     194.382350
# 18520           62.0       False      failed      62.000000   15000.000000
# 2941             2.0       False        live       2.000000   10000.000000
#
#                  sub_category  blurb_length
# id
# 2147476221             drinks          20.0
# 2147466649           fine art          22.0
# 2147460119     conceptual art          21.0
# 2147450956     tabletop games          23.0
# 2147437278  community gardens          18.0
# ...                       ...           ...
# 33867           ready-to-wear          23.0
# 24380                  spaces          24.0
# 21109         performance art          24.0
# 18520             world music          24.0
# 2941                      NaN          18.0
#
# [222555 rows x 13 columns]

# %%
# which columns have NaN 
data_clean.isna().sum()
# Out:
# backers_count                   0
# category                        0
# country_displayable_name    20310
# created_at                      0
# deadline                        0
# id                              0
# launched_at                     0
# pledged                         0
# staff_pick                      0
# state                           0
# usd_pledged                     1
# goal_convert                    0
# sub_category                14730
# blurb_length                    8
# dtype: int64

# %%
# display null values
null_data = data_clean[data_clean.isnull().any(axis=1)]
null_data
# Out:
#         backers_count      category country_displayable_name  \
# 11                 70  film & video                      NaN
# 16                113         dance        the United States
# 19                709    technology                      NaN
# 22                 13         dance        the United States
# 37                 43         music                      NaN
# ...               ...           ...                      ...
# 222525              0          food                      NaN
# 222531             79         music                      NaN
# 222534             42    publishing                      NaN
# 222541            140           art        the United States
# 222554              2       fashion        the United States
#
#                  created_at             deadline          id  \
# 11      2014-01-10 19:03:28  2014-04-10 23:18:36  2147380316
# 16      2014-07-04 17:30:54  2014-08-08 05:01:00  2147364781
# 19      2017-06-01 12:43:16  2017-08-18 18:00:00  2147345648
# 22      2012-02-02 15:06:14  2012-03-30 13:57:00  2147336747
# 37      2013-01-26 16:51:42  2013-03-01 20:59:58  2147176559
# ...                     ...                  ...         ...
# 222525  2018-01-06 17:12:16  2018-03-07 19:42:27      288910
# 222531  2013-01-06 02:47:44  2013-02-10 16:49:37      197154
# 222534  2019-04-12 12:02:29  2019-06-12 21:00:00      171116
# 222541  2019-08-31 15:15:01  2019-10-20 18:59:27       54546
# 222554  2020-01-06 14:19:05  2020-03-06 19:52:18        2941
#
#                 launched_at   pledged  staff_pick       state   usd_pledged  \
# 11      2014-02-25 00:18:36   6740.00       False  successful   6740.000000
# 16      2014-07-07 21:41:00  14360.40        True  successful  14360.400000
# 19      2017-07-26 13:13:04  70751.00       False  successful  70751.000000
# 22      2012-02-21 17:56:31    601.00       False  successful    601.000000
# 37      2013-02-07 20:59:58   3520.00       False  successful   5511.945437
# ...                     ...       ...         ...         ...           ...
# 222525  2018-01-06 19:42:27      0.00       False      failed      0.000000
# 222531  2013-01-11 16:49:37   1593.99        True  successful   1593.990000
# 222534  2019-05-13 12:58:30   2048.00       False  successful   2048.000000
# 222541  2019-09-20 18:59:27  12216.00       False  successful  12216.000000
# 222554  2020-01-06 19:52:18      2.00       False        live      2.000000
#
#         goal_convert      sub_category  blurb_length
# 11        6500.00000    narrative film          21.0
# 16       13000.00000               NaN          21.0
# 19       12000.00000          software          17.0
# 22         500.00000               NaN          21.0
# 37        4315.67563           hip-hop          24.0
# ...              ...               ...           ...
# 222525    5000.00000       restaurants          17.0
# 222531    1450.00000        indie rock          20.0
# 222534    2000.00000  radio & podcasts           5.0
# 222541   10000.00000               NaN          20.0
# 222554   10000.00000               NaN          18.0
#
# [33312 rows x 14 columns]

# %%
#replace NaN in sub_category with none. blurb and usd_pledged to 0
data_clean['sub_category'] = data_clean['sub_category'].replace(np.nan, 'none')
data_clean['blurb_length'] = data_clean['blurb_length'].replace(np.nan, '0')
data_clean['usd_pledged'] = data_clean['usd_pledged'].replace(np.nan, '0')

# %%
# see if NaN has been fixed
data_clean.sub_category.unique()
# Out:
# array(['drinks', 'fine art', 'conceptual art', 'tabletop games',
#        'community gardens', 'classical music', 'indie rock', 'horror',
#        'apparel', 'robots', 'world music', 'narrative film', 'pop',
#        'mixed media', 'people', 'none', 'punk', 'software', 'young adult',
#        'spaces', 'r&b', 'anthologies', 'art books', 'action',
#        'periodicals', 'literary journals', 'photo', 'faith',
#        'illustration', 'digital art', 'photobooks', 'hip-hop',
#        'small batch', 'woodworking', 'video games', 'sound',
#        'product design', 'webseries', 'gaming hardware', 'flight',
#        'restaurants', 'shorts', "children's books", 'places', 'rock',
#        "farmer's markets", 'immersive', 'live games', 'musical',
#        'graphic design', 'web', 'food trucks', 'drama',
#        'radio & podcasts', 'comedy', 'apps', 'country & folk',
#        'diy electronics', 'electronic music', 'vegan', 'poetry',
#        'animation', 'accessories', 'pet fashion', 'webcomics',
#        'documentary', 'jazz', 'puzzles', 'diy', 'comic books',
#        'nonfiction', 'mobile games', 'performance art', 'festivals',
#        'playing cards', 'painting', 'movie theaters', 'television',
#        'metal', 'space exploration', 'ready-to-wear', 'video',
#        'graphic novels', 'printing', 'plays', 'public art', 'audio',
#        'knitting', 'academic', 'nature', 'thrillers', 'hardware',
#        'interactive design', 'sculpture', 'camera equipment',
#        'experimental', 'gadgets', 'events', 'jewelry', 'animals',
#        'video art', 'fiction', 'zines', 'ceramics', 'science fiction',
#        'fantasy', 'wearables', 'music videos', 'typography',
#        'architecture', 'latin', 'weaving', 'literary spaces', 'romance',
#        'couture', 'civic design', 'print', 'farms', 'performances',
#        'textiles', '3d printing', 'installations', 'candles', 'glass',
#        'calendars', 'crochet', 'footwear', 'fabrication tools',
#        'cookbooks', 'family', 'childrenswear', 'embroidery', 'kids',
#        'toys', 'social practice', 'translations', 'quilts', 'makerspaces',
#        'bacon', 'pottery', 'blues', 'workshops', 'residencies',
#        'stationery', 'letterpress', 'chiptune', 'taxidermy'], dtype=object)

# %%
#visual check
data_clean.loc[data_clean['sub_category'] == 'apparel']
# Out:
#         backers_count category country_displayable_name           created_at  \
# 8                  12  fashion        the United States  2016-03-29 03:23:41
# 80                 90  fashion        the United States  2014-05-07 22:30:51
# 99                 86  fashion          the Netherlands  2017-04-07 11:16:11
# 144                 2  fashion        the United States  2019-10-24 23:48:33
# 298                64  fashion                      NaN  2015-04-18 07:34:48
# ...               ...      ...                      ...                  ...
# 222216            149  fashion        the United States  2016-09-21 02:53:05
# 222228             22  fashion                   Canada  2019-10-22 14:37:38
# 222277             18  fashion        the United States  2019-03-12 19:28:12
# 222311              2  fashion        the United States  2020-04-09 15:34:49
# 222409            273  fashion        the United States  2015-06-24 02:11:31
#
#                    deadline          id          launched_at   pledged  \
# 8       2016-05-28 16:54:21  2147392509  2016-03-29 16:54:21    510.00
# 80      2014-07-03 14:49:26  2146692994  2014-06-03 14:49:26  30062.00
# 99      2017-06-22 07:43:43  2146384465  2017-05-23 07:43:43  15144.00
# 144     2020-01-10 19:31:10  2145965871  2019-11-11 19:31:10     21.00
# 298     2015-06-04 11:21:41  2144324105  2015-05-05 11:21:41  21350.00
# ...                     ...         ...                  ...       ...
# 222216  2017-05-21 21:05:55     3255370  2017-04-21 21:05:55   4609.00
# 222228  2019-11-26 21:49:58     3169057  2019-10-27 20:49:58   2017.29
# 222277  2019-05-27 01:01:29     2531347  2019-03-28 01:01:29   1237.00
# 222311  2020-06-15 19:36:05     2233445  2020-04-16 19:36:05     11.00
# 222409  2015-08-31 05:00:00     1314084  2015-07-31 20:42:26  15777.00
#
#         staff_pick       state usd_pledged  goal_convert sub_category  \
# 8            False  successful         510     500.00000      apparel
# 80            True  successful       30062   30000.00000      apparel
# 99           False  successful     16948.6   16501.03290      apparel
# 144          False        live          21    3000.00000      apparel
# 298          False  successful       21350   21000.00000      apparel
# ...            ...         ...         ...           ...          ...
# 222216       False  successful        4609    3000.00000      apparel
# 222228       False        live     1544.84    4907.17513      apparel
# 222277       False  successful        1237    1135.00000      apparel
# 222311       False      failed          11   15000.00000      apparel
# 222409        True  successful       15777   10000.00000      apparel
#
#        blurb_length
# 8                14
# 80               24
# 99               20
# 144               4
# 298              14
# ...             ...
# 222216           15
# 222228            5
# 222277            6
# 222311           18
# 222409           15
#
# [3258 rows x 14 columns]

# %%
# all NaN fixed
data_clean.isna().sum()
# Out:
# backers_count                   0
# category                        0
# country_displayable_name    20310
# created_at                      0
# deadline                        0
# id                              0
# launched_at                     0
# pledged                         0
# staff_pick                      0
# state                           0
# usd_pledged                     0
# goal_convert                    0
# sub_category                    0
# blurb_length                    0
# dtype: int64

# %%
# calculate days between deadline and creation
data_clean[['created_at','deadline','launched_at']] = data_clean[['created_at','deadline','launched_at']].apply(pd.to_datetime) #if conversion required
data_clean['launch_to_deadline'] = (data_clean['deadline'] - data_clean['launched_at']).dt.days
data_clean['creation_to_launch'] = (data_clean['launched_at']- data_clean['created_at']).dt.days

# %%
# day of the week for launch, deadline
data_clean['launch_day'] = data_clean['launched_at'].dt.day_name()
data_clean['deadline_day'] = data_clean['deadline'].dt.day_name()
# month
data_clean['launch_month'] = data_clean['launched_at'].dt.month_name()
data_clean['deadline_month'] = data_clean['deadline'].dt.month_name()

# %%
data_clean
# Out:
#         backers_count     category country_displayable_name  \
# 0                2076         food        the United States
# 1                   0  photography                   Canada
# 2                  53          art        the United States
# 3                 181        games        the United States
# 4                  52         food                   Canada
# ...               ...          ...                      ...
# 222550             42      fashion                   Canada
# 222551             18         food        the United States
# 222552             11          art       the United Kingdom
# 222553              4        music        the United States
# 222554              2      fashion        the United States
#
#                 created_at            deadline          id  \
# 0      2014-11-28 18:42:27 2015-04-10 02:00:00  2147476221
# 1      2014-07-08 19:50:38 2014-07-24 15:23:00  2147466649
# 2      2011-04-25 17:48:20 2011-08-04 04:30:00  2147460119
# 3      2019-09-22 17:11:47 2020-03-19 14:32:55  2147450956
# 4      2014-12-30 17:32:49 2015-02-11 17:26:23  2147437278
# ...                    ...                 ...         ...
# 222550 2015-03-15 04:40:34 2015-07-30 18:28:11       33867
# 222551 2015-10-25 15:32:25 2015-11-26 16:25:33       24380
# 222552 2015-04-07 14:07:05 2015-05-06 21:00:00       21109
# 222553 2016-10-19 12:13:18 2016-11-18 14:32:40       18520
# 222554 2020-01-06 14:19:05 2020-03-06 19:52:18        2941
#
#                launched_at   pledged  staff_pick       state usd_pledged  \
# 0      2015-03-02 15:14:38  304142.0       False  successful      304142
# 1      2014-07-11 18:56:05       0.0       False      failed           0
# 2      2011-06-24 19:29:15   18758.0        True  successful       18758
# 3      2020-02-18 15:33:12    5026.0        True  successful        5026
# 4      2015-01-02 17:26:23    3091.0       False      failed     2660.97
# ...                    ...       ...         ...         ...         ...
# 222550 2015-06-15 18:28:11    2798.0        True      failed     2271.72
# 222551 2015-10-27 15:25:33     776.0       False      failed         776
# 222552 2015-04-07 22:37:44     173.0       False  successful     258.036
# 222553 2016-10-19 13:32:40      62.0       False      failed          62
# 222554 2020-01-06 19:52:18       2.0       False        live           2
#
#          goal_convert       sub_category blurb_length  launch_to_deadline  \
# 0        75000.000000             drinks           20                  38
# 1         1148.763315           fine art           22                  12
# 2        18000.000000     conceptual art           21                  40
# 3          500.000000     tabletop games           23                  29
# 4       179139.466350  community gardens           18                  40
# ...               ...                ...          ...                 ...
# 222550   12767.134500      ready-to-wear           23                  45
# 222551   20000.000000             spaces           24                  30
# 222552     194.382350    performance art           24                  28
# 222553   15000.000000        world music           24                  30
# 222554   10000.000000               none           18                  60
#
#         creation_to_launch launch_day deadline_day launch_month deadline_month
# 0                       93     Monday       Friday        March          April
# 1                        2     Friday     Thursday         July           July
# 2                       60     Friday     Thursday         June         August
# 3                      148    Tuesday     Thursday     February          March
# 4                        2     Friday    Wednesday      January       February
# ...                    ...        ...          ...          ...            ...
# 222550                  92     Monday     Thursday         June           July
# 222551                   1    Tuesday     Thursday      October       November
# 222552                   0    Tuesday    Wednesday        April            May
# 222553                   0  Wednesday       Friday      October       November
# 222554                   0     Monday       Friday      January          March
#
# [222555 rows x 20 columns]

# %%
# Launch time
data_clean['launch_hour'] = data_clean['launched_at'].dt.hour 

def two_hour_bucket(row):
    if row['launch_hour'] in (0,1):
        return '12am-2am'
    if row['launch_hour'] in (2,3):
        return '2am-4am'
    if row['launch_hour'] in (4,5):
        return '4am-6am'
    if row['launch_hour'] in (6,7):
        return '6am-8am'
    if row['launch_hour'] in (8,9):
        return '8am-10am'
    if row['launch_hour'] in (10,11):
        return '10am-12pm'
    if row['launch_hour'] in (12,13):
        return '12pm-2pm'
    if row['launch_hour'] in (14,15):
        return '2pm-4pm'
    if row['launch_hour'] in (16,17):
        return '4pm-6pm'
    if row['launch_hour'] in (18,19):
        return '6pm-8pm'
    if row['launch_hour'] in (20,21):
        return '8pm-10pm'
    if row['launch_hour'] in (22,23):
        return '10pm-12am'
    
data_clean['launch_time'] = data_clean.apply(two_hour_bucket, axis=1) 
data_clean.drop('launch_hour', axis=1, inplace=True)

# %%
data_clean
# Out:
#         backers_count     category country_displayable_name  \
# 0                2076         food        the United States
# 1                   0  photography                   Canada
# 2                  53          art        the United States
# 3                 181        games        the United States
# 4                  52         food                   Canada
# ...               ...          ...                      ...
# 222550             42      fashion                   Canada
# 222551             18         food        the United States
# 222552             11          art       the United Kingdom
# 222553              4        music        the United States
# 222554              2      fashion        the United States
#
#                 created_at            deadline          id  \
# 0      2014-11-28 18:42:27 2015-04-10 02:00:00  2147476221
# 1      2014-07-08 19:50:38 2014-07-24 15:23:00  2147466649
# 2      2011-04-25 17:48:20 2011-08-04 04:30:00  2147460119
# 3      2019-09-22 17:11:47 2020-03-19 14:32:55  2147450956
# 4      2014-12-30 17:32:49 2015-02-11 17:26:23  2147437278
# ...                    ...                 ...         ...
# 222550 2015-03-15 04:40:34 2015-07-30 18:28:11       33867
# 222551 2015-10-25 15:32:25 2015-11-26 16:25:33       24380
# 222552 2015-04-07 14:07:05 2015-05-06 21:00:00       21109
# 222553 2016-10-19 12:13:18 2016-11-18 14:32:40       18520
# 222554 2020-01-06 14:19:05 2020-03-06 19:52:18        2941
#
#                launched_at   pledged  staff_pick       state  ...  \
# 0      2015-03-02 15:14:38  304142.0       False  successful  ...
# 1      2014-07-11 18:56:05       0.0       False      failed  ...
# 2      2011-06-24 19:29:15   18758.0        True  successful  ...
# 3      2020-02-18 15:33:12    5026.0        True  successful  ...
# 4      2015-01-02 17:26:23    3091.0       False      failed  ...
# ...                    ...       ...         ...         ...  ...
# 222550 2015-06-15 18:28:11    2798.0        True      failed  ...
# 222551 2015-10-27 15:25:33     776.0       False      failed  ...
# 222552 2015-04-07 22:37:44     173.0       False  successful  ...
# 222553 2016-10-19 13:32:40      62.0       False      failed  ...
# 222554 2020-01-06 19:52:18       2.0       False        live  ...
#
#          goal_convert       sub_category blurb_length launch_to_deadline  \
# 0        75000.000000             drinks           20                 38
# 1         1148.763315           fine art           22                 12
# 2        18000.000000     conceptual art           21                 40
# 3          500.000000     tabletop games           23                 29
# 4       179139.466350  community gardens           18                 40
# ...               ...                ...          ...                ...
# 222550   12767.134500      ready-to-wear           23                 45
# 222551   20000.000000             spaces           24                 30
# 222552     194.382350    performance art           24                 28
# 222553   15000.000000        world music           24                 30
# 222554   10000.000000               none           18                 60
#
#         creation_to_launch  launch_day deadline_day launch_month  \
# 0                       93      Monday       Friday        March
# 1                        2      Friday     Thursday         July
# 2                       60      Friday     Thursday         June
# 3                      148     Tuesday     Thursday     February
# 4                        2      Friday    Wednesday      January
# ...                    ...         ...          ...          ...
# 222550                  92      Monday     Thursday         June
# 222551                   1     Tuesday     Thursday      October
# 222552                   0     Tuesday    Wednesday        April
# 222553                   0   Wednesday       Friday      October
# 222554                   0      Monday       Friday      January
#
#        deadline_month launch_time
# 0               April     2pm-4pm
# 1                July     6pm-8pm
# 2              August     6pm-8pm
# 3               March     2pm-4pm
# 4            February     4pm-6pm
# ...               ...         ...
# 222550           July     6pm-8pm
# 222551       November     2pm-4pm
# 222552            May   10pm-12am
# 222553       November    12pm-2pm
# 222554          March     6pm-8pm
#
# [222555 rows x 21 columns]

# %%
data_clean.launch_time.unique()
# Out:
# array(['2pm-4pm', '6pm-8pm', '4pm-6pm', '6am-8am', '10pm-12am', '4am-6am',
#        '8am-10am', '12am-2am', '10am-12pm', '8pm-10pm', '12pm-2pm',
#        '2am-4am'], dtype=object)

# %%
# deadline time
data_clean['deadline_hour'] = data_clean['deadline'].dt.hour 

def two_hour_bucket(row):
    if row['deadline_hour'] in (0,1):
        return '12am-2am'
    if row['deadline_hour'] in (2,3):
        return '2am-4am'
    if row['deadline_hour'] in (4,5):
        return '4am-6am'
    if row['deadline_hour'] in (6,7):
        return '6am-8am'
    if row['deadline_hour'] in (8,9):
        return '8am-10am'
    if row['deadline_hour'] in (10,11):
        return '10am-12pm'
    if row['deadline_hour'] in (12,13):
        return '12pm-2pm'
    if row['deadline_hour'] in (14,15):
        return '2pm-4pm'
    if row['deadline_hour'] in (16,17):
        return '4pm-6pm'
    if row['deadline_hour'] in (18,19):
        return '6pm-8pm'
    if row['deadline_hour'] in (20,21):
        return '8pm-10pm'
    if row['deadline_hour'] in (22,23):
        return '10pm-12am'
    
data_clean['deadline_time'] = data_clean.apply(two_hour_bucket, axis=1) 
data_clean.drop('deadline_hour', axis=1, inplace=True)

# %%
data_clean.deadline_time.unique()
# Out:
# array(['2am-4am', '2pm-4pm', '4am-6am', '4pm-6pm', '6am-8am', '10pm-12am',
#        '8am-10am', '10am-12pm', '12pm-2pm', '6pm-8pm', '12am-2am',
#        '8pm-10pm'], dtype=object)

# %%
# removing suspended, live, and cancelled campaigns
data_clean.state.value_counts()
# Out:
# successful    113716
# failed         80013
# live           18658
# canceled        9512
# suspended        656
# Name: state, dtype: int64

# %%
# removing suspended, live, and cancelled campaigns
data_clean = data_clean[~data_clean.state.str.contains("live")]
data_clean = data_clean[~data_clean.state.str.contains("canceled")]
data_clean = data_clean[~data_clean.state.str.contains("suspended")]

# %%
data_clean.state.value_counts()
# Out:
# successful    113716
# failed         80013
# Name: state, dtype: int64

# %%
data_clean.head()
# Out:
#    backers_count     category country_displayable_name          created_at  \
# 0           2076         food        the United States 2014-11-28 18:42:27
# 1              0  photography                   Canada 2014-07-08 19:50:38
# 2             53          art        the United States 2011-04-25 17:48:20
# 3            181        games        the United States 2019-09-22 17:11:47
# 4             52         food                   Canada 2014-12-30 17:32:49
#
#              deadline          id         launched_at   pledged  staff_pick  \
# 0 2015-04-10 02:00:00  2147476221 2015-03-02 15:14:38  304142.0       False
# 1 2014-07-24 15:23:00  2147466649 2014-07-11 18:56:05       0.0       False
# 2 2011-08-04 04:30:00  2147460119 2011-06-24 19:29:15   18758.0        True
# 3 2020-03-19 14:32:55  2147450956 2020-02-18 15:33:12    5026.0        True
# 4 2015-02-11 17:26:23  2147437278 2015-01-02 17:26:23    3091.0       False
#
#         state  ...       sub_category  blurb_length launch_to_deadline  \
# 0  successful  ...             drinks            20                 38
# 1      failed  ...           fine art            22                 12
# 2  successful  ...     conceptual art            21                 40
# 3  successful  ...     tabletop games            23                 29
# 4      failed  ...  community gardens            18                 40
#
#   creation_to_launch  launch_day  deadline_day launch_month deadline_month  \
# 0                 93      Monday        Friday        March          April
# 1                  2      Friday      Thursday         July           July
# 2                 60      Friday      Thursday         June         August
# 3                148     Tuesday      Thursday     February          March
# 4                  2      Friday     Wednesday      January       February
#
#   launch_time deadline_time
# 0     2pm-4pm       2am-4am
# 1     6pm-8pm       2pm-4pm
# 2     6pm-8pm       4am-6am
# 3     2pm-4pm       2pm-4pm
# 4     4pm-6pm       4pm-6pm
#
# [5 rows x 22 columns]

# %%
#latest_data = data_clean.drop(data_clean.columns[0], axis = 1)
latest_data = data_clean#.set_index('id')
latest_data = latest_data.drop_duplicates()
latest_data
# Out:
#         backers_count     category country_displayable_name  \
# 0                2076         food        the United States
# 1                   0  photography                   Canada
# 2                  53          art        the United States
# 3                 181        games        the United States
# 4                  52         food                   Canada
# ...               ...          ...                      ...
# 222549              3         food        the United States
# 222550             42      fashion                   Canada
# 222551             18         food        the United States
# 222552             11          art       the United Kingdom
# 222553              4        music        the United States
#
#                 created_at            deadline          id  \
# 0      2014-11-28 18:42:27 2015-04-10 02:00:00  2147476221
# 1      2014-07-08 19:50:38 2014-07-24 15:23:00  2147466649
# 2      2011-04-25 17:48:20 2011-08-04 04:30:00  2147460119
# 3      2019-09-22 17:11:47 2020-03-19 14:32:55  2147450956
# 4      2014-12-30 17:32:49 2015-02-11 17:26:23  2147437278
# ...                    ...                 ...         ...
# 222549 2018-08-22 02:02:08 2018-10-21 03:51:56       38736
# 222550 2015-03-15 04:40:34 2015-07-30 18:28:11       33867
# 222551 2015-10-25 15:32:25 2015-11-26 16:25:33       24380
# 222552 2015-04-07 14:07:05 2015-05-06 21:00:00       21109
# 222553 2016-10-19 12:13:18 2016-11-18 14:32:40       18520
#
#                launched_at   pledged  staff_pick       state  ...  \
# 0      2015-03-02 15:14:38  304142.0       False  successful  ...
# 1      2014-07-11 18:56:05       0.0       False      failed  ...
# 2      2011-06-24 19:29:15   18758.0        True  successful  ...
# 3      2020-02-18 15:33:12    5026.0        True  successful  ...
# 4      2015-01-02 17:26:23    3091.0       False      failed  ...
# ...                    ...       ...         ...         ...  ...
# 222549 2018-08-22 03:51:56      96.0       False      failed  ...
# 222550 2015-06-15 18:28:11    2798.0        True      failed  ...
# 222551 2015-10-27 15:25:33     776.0       False      failed  ...
# 222552 2015-04-07 22:37:44     173.0       False  successful  ...
# 222553 2016-10-19 13:32:40      62.0       False      failed  ...
#
#              sub_category  blurb_length launch_to_deadline creation_to_launch  \
# 0                  drinks            20                 38                 93
# 1                fine art            22                 12                  2
# 2          conceptual art            21                 40                 60
# 3          tabletop games            23                 29                148
# 4       community gardens            18                 40                  2
# ...                   ...           ...                ...                ...
# 222549             drinks            21                 60                  0
# 222550      ready-to-wear            23                 45                 92
# 222551             spaces            24                 30                  1
# 222552    performance art            24                 28                  0
# 222553        world music            24                 30                  0
#
#         launch_day  deadline_day launch_month deadline_month launch_time  \
# 0           Monday        Friday        March          April     2pm-4pm
# 1           Friday      Thursday         July           July     6pm-8pm
# 2           Friday      Thursday         June         August     6pm-8pm
# 3          Tuesday      Thursday     February          March     2pm-4pm
# 4           Friday     Wednesday      January       February     4pm-6pm
# ...            ...           ...          ...            ...         ...
# 222549   Wednesday        Sunday       August        October     2am-4am
# 222550      Monday      Thursday         June           July     6pm-8pm
# 222551     Tuesday      Thursday      October       November     2pm-4pm
# 222552     Tuesday     Wednesday        April            May   10pm-12am
# 222553   Wednesday        Friday      October       November    12pm-2pm
#
#        deadline_time
# 0            2am-4am
# 1            2pm-4pm
# 2            4am-6am
# 3            2pm-4pm
# 4            4pm-6pm
# ...              ...
# 222549       2am-4am
# 222550       6pm-8pm
# 222551       4pm-6pm
# 222552      8pm-10pm
# 222553       2pm-4pm
#
# [193729 rows x 22 columns]

# %%
# pd.set_option('display.max_columns', None)
# latest_data

# %%
#match the same columns to the previous data set so everything feeds correctly down the pipeline
latest_data = latest_data[['backers_count','category','country_displayable_name','created_at','deadline','goal_convert','id','launched_at','pledged','staff_pick','state','usd_pledged','sub_category','blurb_length','launch_to_deadline','creation_to_launch','launch_day','deadline_day','launch_month','deadline_month','launch_time','deadline_time']]
latest_data
# Out:
#         backers_count     category country_displayable_name  \
# 0                2076         food        the United States
# 1                   0  photography                   Canada
# 2                  53          art        the United States
# 3                 181        games        the United States
# 4                  52         food                   Canada
# ...               ...          ...                      ...
# 222549              3         food        the United States
# 222550             42      fashion                   Canada
# 222551             18         food        the United States
# 222552             11          art       the United Kingdom
# 222553              4        music        the United States
#
#                 created_at            deadline   goal_convert          id  \
# 0      2014-11-28 18:42:27 2015-04-10 02:00:00   75000.000000  2147476221
# 1      2014-07-08 19:50:38 2014-07-24 15:23:00    1148.763315  2147466649
# 2      2011-04-25 17:48:20 2011-08-04 04:30:00   18000.000000  2147460119
# 3      2019-09-22 17:11:47 2020-03-19 14:32:55     500.000000  2147450956
# 4      2014-12-30 17:32:49 2015-02-11 17:26:23  179139.466350  2147437278
# ...                    ...                 ...            ...         ...
# 222549 2018-08-22 02:02:08 2018-10-21 03:51:56    2500.000000       38736
# 222550 2015-03-15 04:40:34 2015-07-30 18:28:11   12767.134500       33867
# 222551 2015-10-25 15:32:25 2015-11-26 16:25:33   20000.000000       24380
# 222552 2015-04-07 14:07:05 2015-05-06 21:00:00     194.382350       21109
# 222553 2016-10-19 12:13:18 2016-11-18 14:32:40   15000.000000       18520
#
#                launched_at   pledged  staff_pick  ...       sub_category  \
# 0      2015-03-02 15:14:38  304142.0       False  ...             drinks
# 1      2014-07-11 18:56:05       0.0       False  ...           fine art
# 2      2011-06-24 19:29:15   18758.0        True  ...     conceptual art
# 3      2020-02-18 15:33:12    5026.0        True  ...     tabletop games
# 4      2015-01-02 17:26:23    3091.0       False  ...  community gardens
# ...                    ...       ...         ...  ...                ...
# 222549 2018-08-22 03:51:56      96.0       False  ...             drinks
# 222550 2015-06-15 18:28:11    2798.0        True  ...      ready-to-wear
# 222551 2015-10-27 15:25:33     776.0       False  ...             spaces
# 222552 2015-04-07 22:37:44     173.0       False  ...    performance art
# 222553 2016-10-19 13:32:40      62.0       False  ...        world music
#
#        blurb_length launch_to_deadline creation_to_launch  launch_day  \
# 0                20                 38                 93      Monday
# 1                22                 12                  2      Friday
# 2                21                 40                 60      Friday
# 3                23                 29                148     Tuesday
# 4                18                 40                  2      Friday
# ...             ...                ...                ...         ...
# 222549           21                 60                  0   Wednesday
# 222550           23                 45                 92      Monday
# 222551           24                 30                  1     Tuesday
# 222552           24                 28                  0     Tuesday
# 222553           24                 30                  0   Wednesday
#
#         deadline_day launch_month deadline_month launch_time deadline_time
# 0             Friday        March          April     2pm-4pm       2am-4am
# 1           Thursday         July           July     6pm-8pm       2pm-4pm
# 2           Thursday         June         August     6pm-8pm       4am-6am
# 3           Thursday     February          March     2pm-4pm       2pm-4pm
# 4          Wednesday      January       February     4pm-6pm       4pm-6pm
# ...              ...          ...            ...         ...           ...
# 222549        Sunday       August        October     2am-4am       2am-4am
# 222550      Thursday         June           July     6pm-8pm       6pm-8pm
# 222551      Thursday      October       November     2pm-4pm       4pm-6pm
# 222552     Wednesday        April            May   10pm-12am      8pm-10pm
# 222553        Friday      October       November    12pm-2pm       2pm-4pm
#
# [193729 rows x 22 columns]

# %%
latest_data = latest_data.drop_duplicates()
latest_data = latest_data.dropna()

# %%
latest_data
# Out:
#         backers_count     category country_displayable_name  \
# 0                2076         food        the United States
# 1                   0  photography                   Canada
# 2                  53          art        the United States
# 3                 181        games        the United States
# 4                  52         food                   Canada
# ...               ...          ...                      ...
# 222549              3         food        the United States
# 222550             42      fashion                   Canada
# 222551             18         food        the United States
# 222552             11          art       the United Kingdom
# 222553              4        music        the United States
#
#                 created_at            deadline   goal_convert          id  \
# 0      2014-11-28 18:42:27 2015-04-10 02:00:00   75000.000000  2147476221
# 1      2014-07-08 19:50:38 2014-07-24 15:23:00    1148.763315  2147466649
# 2      2011-04-25 17:48:20 2011-08-04 04:30:00   18000.000000  2147460119
# 3      2019-09-22 17:11:47 2020-03-19 14:32:55     500.000000  2147450956
# 4      2014-12-30 17:32:49 2015-02-11 17:26:23  179139.466350  2147437278
# ...                    ...                 ...            ...         ...
# 222549 2018-08-22 02:02:08 2018-10-21 03:51:56    2500.000000       38736
# 222550 2015-03-15 04:40:34 2015-07-30 18:28:11   12767.134500       33867
# 222551 2015-10-25 15:32:25 2015-11-26 16:25:33   20000.000000       24380
# 222552 2015-04-07 14:07:05 2015-05-06 21:00:00     194.382350       21109
# 222553 2016-10-19 12:13:18 2016-11-18 14:32:40   15000.000000       18520
#
#                launched_at   pledged  staff_pick  ...       sub_category  \
# 0      2015-03-02 15:14:38  304142.0       False  ...             drinks
# 1      2014-07-11 18:56:05       0.0       False  ...           fine art
# 2      2011-06-24 19:29:15   18758.0        True  ...     conceptual art
# 3      2020-02-18 15:33:12    5026.0        True  ...     tabletop games
# 4      2015-01-02 17:26:23    3091.0       False  ...  community gardens
# ...                    ...       ...         ...  ...                ...
# 222549 2018-08-22 03:51:56      96.0       False  ...             drinks
# 222550 2015-06-15 18:28:11    2798.0        True  ...      ready-to-wear
# 222551 2015-10-27 15:25:33     776.0       False  ...             spaces
# 222552 2015-04-07 22:37:44     173.0       False  ...    performance art
# 222553 2016-10-19 13:32:40      62.0       False  ...        world music
#
#        blurb_length launch_to_deadline creation_to_launch  launch_day  \
# 0                20                 38                 93      Monday
# 1                22                 12                  2      Friday
# 2                21                 40                 60      Friday
# 3                23                 29                148     Tuesday
# 4                18                 40                  2      Friday
# ...             ...                ...                ...         ...
# 222549           21                 60                  0   Wednesday
# 222550           23                 45                 92      Monday
# 222551           24                 30                  1     Tuesday
# 222552           24                 28                  0     Tuesday
# 222553           24                 30                  0   Wednesday
#
#         deadline_day launch_month deadline_month launch_time deadline_time
# 0             Friday        March          April     2pm-4pm       2am-4am
# 1           Thursday         July           July     6pm-8pm       2pm-4pm
# 2           Thursday         June         August     6pm-8pm       4am-6am
# 3           Thursday     February          March     2pm-4pm       2pm-4pm
# 4          Wednesday      January       February     4pm-6pm       4pm-6pm
# ...              ...          ...            ...         ...           ...
# 222549        Sunday       August        October     2am-4am       2am-4am
# 222550      Thursday         June           July     6pm-8pm       6pm-8pm
# 222551      Thursday      October       November     2pm-4pm       4pm-6pm
# 222552     Wednesday        April            May   10pm-12am      8pm-10pm
# 222553        Friday      October       November    12pm-2pm       2pm-4pm
#
# [175646 rows x 22 columns]

# %%
latest_data= latest_data.sort_values(by=['goal_convert'])
latest_data.tail(50)
latest_data.to_csv( "../../../final_product/data/largevalues.csv", index='id')

# %%
latest_data.isnull().sum()
# Out:
# backers_count               0
# category                    0
# country_displayable_name    0
# created_at                  0
# deadline                    0
# goal_convert                0
# id                          0
# launched_at                 0
# pledged                     0
# staff_pick                  0
# state                       0
# usd_pledged                 0
# sub_category                0
# blurb_length                0
# launch_to_deadline          0
# creation_to_launch          0
# launch_day                  0
# deadline_day                0
# launch_month                0
# deadline_month              0
# launch_time                 0
# deadline_time               0
# dtype: int64

# %%
latest_data.to_csv( "../../../final_product/data/latest_data.csv", index='id')
