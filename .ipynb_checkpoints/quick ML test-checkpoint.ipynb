# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, f1_score, precision_recall_fscore_support
import matplotlib.pyplot as plt
import itertools
import time

# %%
df = pd.read_csv('data/latest_data.csv',index_col='Unnamed: 0')
df.head()
# Out:
# /Users/laurentvanhassel/anaconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#             backers_count     category country_displayable_name  \
# Unnamed: 0
# 0                       3         food        the United States
# 1                       6   technology       the United Kingdom
# 2                      90  photography        the United States
# 3                     205  photography       the United Kingdom
# 4                      35          art        the United States
#
#                      created_at             deadline    goal  \
# Unnamed: 0
# 0           2014-08-30 01:10:21  2014-10-02 15:44:07   400.0
# 1           2015-02-18 17:15:56  2015-03-20 20:59:26   200.0
# 2           2018-07-28 02:07:21  2018-08-27 13:18:38  2500.0
# 3           2018-02-10 14:42:07  2018-04-05 06:42:32  9500.0
# 4           2012-07-25 23:21:04  2012-09-11 03:59:00  4000.0
#
#                     launched_at  pledged  staff_pick       state  ...  \
# Unnamed: 0                                                        ...
# 0           2014-09-02 15:44:07     15.0       False      failed  ...
# 1           2015-02-18 21:59:26     28.0       False      failed  ...
# 2           2018-07-28 13:18:38   4350.0       False  successful  ...
# 3           2018-03-06 07:42:32  10181.0       False  successful  ...
# 4           2012-08-27 20:40:13   4254.0       False  successful  ...
#
#             sub_category blurb_length  launch_to_deadline  creation_to_launch  \
# Unnamed: 0
# 0            small batch         28.0                  30                   3
# 1               software         22.0                  29                   0
# 2             photobooks         18.0                  30                   0
# 3             photobooks         19.0                  29                  23
# 4             public art         25.0                  14                  32
#
#             launch_day deadline_day launch_month deadline_month launch_time  \
# Unnamed: 0
# 0              Tuesday     Thursday    September        October     2pm-4pm
# 1            Wednesday       Friday     February          March    8pm-10pm
# 2             Saturday       Monday         July         August    12pm-2pm
# 3              Tuesday     Thursday        March          April     6am-8am
# 4               Monday      Tuesday       August      September    8pm-10pm
#
#            deadline_time
# Unnamed: 0
# 0                2pm-4pm
# 1               8pm-10pm
# 2               12pm-2pm
# 3                6am-8am
# 4                2am-4am
#
# [5 rows x 21 columns]

# %%
df = df.drop(columns=['created_at', 'deadline','launched_at'])

# %%
df.describe()
# Out:
#        backers_count          goal       pledged   usd_pledged  blurb_length  \
# count   2.359293e+06  2.359293e+06  2.359293e+06  2.359293e+06  2.359293e+06
# mean    1.572820e+02  4.647968e+04  2.481069e+04  1.429776e+04  1.827985e+01
# std     9.574799e+02  1.148106e+06  8.851189e+05  1.104990e+05  5.391331e+00
# min     0.000000e+00  1.000000e-02  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     5.000000e+00  1.500000e+03  1.750000e+02  1.660000e+02  1.500000e+01
# 50%     3.200000e+01  5.000000e+03  1.918000e+03  1.847699e+03  1.900000e+01
# 75%     9.800000e+01  1.400000e+04  7.741000e+03  7.220371e+03  2.200000e+01
# max     1.058570e+05  1.000000e+08  4.816218e+08  1.296961e+07  4.300000e+01
#
#        launch_to_deadline  creation_to_launch
# count        2.359293e+06        2.359293e+06
# mean         3.239105e+01        4.813088e+01
# std          1.193677e+01        1.369898e+02
# min          1.000000e+00        0.000000e+00
# 25%          2.900000e+01        3.000000e+00
# 50%          3.000000e+01        1.100000e+01
# 75%          3.400000e+01        3.700000e+01
# max          9.700000e+01        3.303000e+03

# %%
df.state.count()
# Out:
# 2359293

# %%
df
# Out:
#             backers_count      category country_displayable_name     goal  \
# Unnamed: 0
# 0                       3          food        the United States    400.0
# 1                       6    technology       the United Kingdom    200.0
# 2                      90   photography        the United States   2500.0
# 3                     205   photography       the United Kingdom   9500.0
# 4                      35           art        the United States   4000.0
# ...                   ...           ...                      ...      ...
# 2546508                51       fashion        the United States    500.0
# 2546510               175         music        the United States  10000.0
# 2546511               972  film & video       the United Kingdom  80000.0
# 2546512                 3  film & video                  Ireland   5000.0
# 2546515               108       fashion        the United States    500.0
#
#             pledged  staff_pick       state    usd_pledged sub_category  \
# Unnamed: 0
# 0              15.0       False      failed      15.000000  small batch
# 1              28.0       False      failed      43.041761     software
# 2            4350.0       False  successful    4350.000000   photobooks
# 3           10181.0       False  successful   14043.223538   photobooks
# 4            4254.0       False  successful    4254.000000   public art
# ...             ...         ...         ...            ...          ...
# 2546508      1350.0       False  successful    1350.000000  accessories
# 2546510     10260.0       False  successful   10260.000000         jazz
# 2546511     90090.5        True  successful  126911.265732       horror
# 2546512        41.0       False      failed      45.952431       horror
# 2546515      3300.0       False  successful    3300.000000  accessories
#
#             blurb_length  launch_to_deadline  creation_to_launch launch_day  \
# Unnamed: 0
# 0                   28.0                  30                   3    Tuesday
# 1                   22.0                  29                   0  Wednesday
# 2                   18.0                  30                   0   Saturday
# 3                   19.0                  29                  23    Tuesday
# 4                   25.0                  14                  32     Monday
# ...                  ...                 ...                 ...        ...
# 2546508              9.0                  14                   2     Monday
# 2546510             18.0                  31                 106     Monday
# 2546511             11.0                  30                  11     Monday
# 2546512             20.0                  30                   0     Sunday
# 2546515             22.0                  26                  12  Wednesday
#
#            deadline_day launch_month deadline_month launch_time deadline_time
# Unnamed: 0
# 0              Thursday    September        October     2pm-4pm       2pm-4pm
# 1                Friday     February          March    8pm-10pm      8pm-10pm
# 2                Monday         July         August    12pm-2pm      12pm-2pm
# 3              Thursday        March          April     6am-8am       6am-8am
# 4               Tuesday       August      September    8pm-10pm       2am-4am
# ...                 ...          ...            ...         ...           ...
# 2546508          Monday      January       February     6pm-8pm       6pm-8pm
# 2546510        Thursday          May           June     6pm-8pm       6pm-8pm
# 2546511       Wednesday        April            May     2pm-4pm       6pm-8pm
# 2546512         Tuesday          May           June     4pm-6pm       4pm-6pm
# 2546515         Tuesday        March          April     6pm-8pm       6am-8am
#
# [2359293 rows x 18 columns]

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
cate_counts = df.launch_time.value_counts()
cate_counts
# Out:
# 4pm-6pm      343048
# 6pm-8pm      300749
# 2pm-4pm      298786
# 8pm-10pm     269740
# 10pm-12am    227882
# 12pm-2pm     187224
# 12am-2am     179625
# 2am-4am      140728
# 4am-6am      119446
# 10am-12pm    108275
# 6am-8am       94925
# 8am-10am      88865
# Name: launch_time, dtype: int64

# %%
df.dtypes
# Out:
# backers_count                 int64
# category                     object
# country_displayable_name     object
# goal                        float64
# pledged                     float64
# staff_pick                     bool
# state                        object
# usd_pledged                 float64
# sub_category                 object
# blurb_length                float64
# launch_to_deadline            int64
# creation_to_launch            int64
# launch_day                   object
# deadline_day                 object
# launch_month                 object
# deadline_month               object
# launch_time                  object
# deadline_time                object
# dtype: object

# %%
# need to convert bool to str
df['staff_pick'] = df['staff_pick'].astype(str)
df
# Out:
#             backers_count      category country_displayable_name     goal  \
# Unnamed: 0
# 0                       3          food        the United States    400.0
# 1                       6    technology       the United Kingdom    200.0
# 2                      90   photography        the United States   2500.0
# 3                     205   photography       the United Kingdom   9500.0
# 4                      35           art        the United States   4000.0
# ...                   ...           ...                      ...      ...
# 2546508                51       fashion        the United States    500.0
# 2546510               175         music        the United States  10000.0
# 2546511               972  film & video       the United Kingdom  80000.0
# 2546512                 3  film & video                  Ireland   5000.0
# 2546515               108       fashion        the United States    500.0
#
#             pledged staff_pick       state    usd_pledged sub_category  \
# Unnamed: 0
# 0              15.0      False      failed      15.000000  small batch
# 1              28.0      False      failed      43.041761     software
# 2            4350.0      False  successful    4350.000000   photobooks
# 3           10181.0      False  successful   14043.223538   photobooks
# 4            4254.0      False  successful    4254.000000   public art
# ...             ...        ...         ...            ...          ...
# 2546508      1350.0      False  successful    1350.000000  accessories
# 2546510     10260.0      False  successful   10260.000000         jazz
# 2546511     90090.5       True  successful  126911.265732       horror
# 2546512        41.0      False      failed      45.952431       horror
# 2546515      3300.0      False  successful    3300.000000  accessories
#
#             blurb_length  launch_to_deadline  creation_to_launch launch_day  \
# Unnamed: 0
# 0                   28.0                  30                   3    Tuesday
# 1                   22.0                  29                   0  Wednesday
# 2                   18.0                  30                   0   Saturday
# 3                   19.0                  29                  23    Tuesday
# 4                   25.0                  14                  32     Monday
# ...                  ...                 ...                 ...        ...
# 2546508              9.0                  14                   2     Monday
# 2546510             18.0                  31                 106     Monday
# 2546511             11.0                  30                  11     Monday
# 2546512             20.0                  30                   0     Sunday
# 2546515             22.0                  26                  12  Wednesday
#
#            deadline_day launch_month deadline_month launch_time deadline_time
# Unnamed: 0
# 0              Thursday    September        October     2pm-4pm       2pm-4pm
# 1                Friday     February          March    8pm-10pm      8pm-10pm
# 2                Monday         July         August    12pm-2pm      12pm-2pm
# 3              Thursday        March          April     6am-8am       6am-8am
# 4               Tuesday       August      September    8pm-10pm       2am-4am
# ...                 ...          ...            ...         ...           ...
# 2546508          Monday      January       February     6pm-8pm       6pm-8pm
# 2546510        Thursday          May           June     6pm-8pm       6pm-8pm
# 2546511       Wednesday        April            May     2pm-4pm       6pm-8pm
# 2546512         Tuesday          May           June     4pm-6pm       4pm-6pm
# 2546515         Tuesday        March          April     6pm-8pm       6am-8am
#
# [2359293 rows x 18 columns]

# %%
df['state'] = df['state'].replace({'failed': 0, 'successful': 1})

# %%
# Generate our categorical variable list
df_object = df.dtypes[df.dtypes == "object"].index.tolist()

# Check the number of unique values in each column
df[df_object].nunique()
# we can see that NAME, APPLICATION_TYPE, CLASSIFICATION will all be issues
# Out:
# category                     15
# country_displayable_name     22
# staff_pick                    2
# sub_category                147
# launch_day                    7
# deadline_day                  7
# launch_month                 12
# deadline_month               12
# launch_time                  12
# deadline_time                12
# dtype: int64

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(df[df_object]))

# Add the encoded variable names to the DataFrame
encode_df.columns = enc.get_feature_names(df_object)
encode_df.head()

# %%
# Merge one-hot encoded features and drop the originals
df = df.merge(encode_df,left_index=True, right_index=True)
df = df.drop(df_object,1)
df.head()

# %%
# Split our preprocessed data into our features and target arrays
y = df["state"].values
X = df.drop(["state"],1).values


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
len(X_train_scaled[0])
# Out:
# 255

# %%
# Define the model - deep neural net
#inputs = 40
#layer one = 80 (2x inputs)
#layer two = 12
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 12

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
#
# 51221/51221 [==============================] - 31s 614us/step - loss: 0.0996 - accuracy: 0.9611
# Epoch 34/50
# 51221/51221 [==============================] - 31s 613us/step - loss: 0.0985 - accuracy: 0.9616
# Epoch 35/50
# 51221/51221 [==============================] - 32s 622us/step - loss: 0.0979 - accuracy: 0.9619
# Epoch 36/50
# 51221/51221 [==============================] - 32s 622us/step - loss: 0.0971 - accuracy: 0.9622
# Epoch 37/50
# 51221/51221 [==============================] - 32s 625us/step - loss: 0.0965 - accuracy: 0.9623
# Epoch 38/50
# 51221/51221 [==============================] - 32s 634us/step - loss: 0.0957 - accuracy: 0.9628
# Epoch 39/50
# 51221/51221 [==============================] - 32s 630us/step - loss: 0.0948 - accuracy: 0.9630
# Epoch 40/50
# 51221/51221 [==============================] - 33s 642us/step - loss: 0.0941 - accuracy: 0.9634
# Epoch 41/50
# 51221/51221 [==============================] - 32s 623us/step - loss: 0.0936 - accuracy: 0.9635
# Epoch 42/50
# 51221/51221 [==============================] - 32s 621us/step - loss: 0.0924 - accuracy: 0.9641
# Epoch 43/50
# 51221/51221 [==============================] - 32s 621us/step - loss: 0.0924 - accuracy: 0.9639
# Epoch 44/50
# 51221/51221 [==============================] - 32s 625us/step - loss: 0.0914 - accuracy: 0.9644
# Epoch 45/50
# 51221/51221 [==============================] - 33s 635us/step - loss: 0.0909 - accuracy: 0.9646
# Epoch 46/50
# 51221/51221 [==============================] - 32s 634us/step - loss: 0.0903 - accuracy: 0.9649
# Epoch 47/50
# 51221/51221 [==============================] - 32s 632us/step - loss: 0.0897 - accuracy: 0.9652
# Epoch 48/50
# 51221/51221 [==============================] - 33s 639us/step - loss: 0.0893 - accuracy: 0.9652
# Epoch 49/50
# 51221/51221 [==============================] - 33s 637us/step - loss: 0.0888 - accuracy: 0.9655
# Epoch 50/50
# 51221/51221 [==============================] - 35s 676us/step - loss: 0.0879 - accuracy: 0.9658

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 17074/17074 - 6s - loss: 0.0881 - accuracy: 0.9663
# Loss: 0.08809952437877655, Accuracy: 0.9662727117538452

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the loss
history_df.plot(y="loss")

# %%
# Plot the loss
history_df.plot(y="accuracy")

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.999

# %%
# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=128, random_state=78)

# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# Evaluate the model
y_pred = rf_model.predict(X_test_scaled)
print(f" Random forest predictive accuracy: {accuracy_score(y_test,y_pred):.3f}")

# %%
df.describe()
# Out:
#        backers_count          goal       pledged   usd_pledged  blurb_length  \
# count   2.359293e+06  2.359293e+06  2.359293e+06  2.359293e+06  2.359293e+06
# mean    1.572820e+02  4.647968e+04  2.481069e+04  1.429776e+04  1.827985e+01
# std     9.574799e+02  1.148106e+06  8.851189e+05  1.104990e+05  5.391331e+00
# min     0.000000e+00  1.000000e-02  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     5.000000e+00  1.500000e+03  1.750000e+02  1.660000e+02  1.500000e+01
# 50%     3.200000e+01  5.000000e+03  1.918000e+03  1.847699e+03  1.900000e+01
# 75%     9.800000e+01  1.400000e+04  7.741000e+03  7.220371e+03  2.200000e+01
# max     1.058570e+05  1.000000e+08  4.816218e+08  1.296961e+07  4.300000e+01
#
#        launch_to_deadline  creation_to_launch
# count        2.359293e+06        2.359293e+06
# mean         3.239105e+01        4.813088e+01
# std          1.193677e+01        1.369898e+02
# min          1.000000e+00        0.000000e+00
# 25%          2.900000e+01        3.000000e+00
# 50%          3.000000e+01        1.100000e+01
# 75%          3.400000e+01        3.700000e+01
# max          9.700000e+01        3.303000e+03
